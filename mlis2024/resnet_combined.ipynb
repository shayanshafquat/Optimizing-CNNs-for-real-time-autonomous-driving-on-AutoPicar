# %%
import pandas as pd
import zipfile
import os
# from io import BytesIO

# Path to your ZIP file
zip_path = 'data.zip'

# Initialize a list to hold your data directory file names
file_list = []

# Use zipfile to open and list contents
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    # Extract training_norm.csv to a pandas DataFrame
    with zip_ref.open('training_norm.csv') as csv_file:
        df = pd.read_csv(csv_file)
    
    # Assuming you want to list files in 'dataset/training_data/training_data'
    # Note: Adjust the path inside the zip as necessary
    for file in zip_ref.namelist():
        if file.startswith('training_data/training_data/') and not file.endswith('/'):
            # Extracts the file name from the path and appends to the list
            file_list.append(os.path.basename(file))

# At this point:
# df contains the DataFrame loaded from training_norm.csv
# file_list contains the list of files in the specified directory within the zip

# %%
file_list
# Out:
# ['1.png',
#  '10.png',
#  '100.png',
#  '1000.png',
#  '10000.png',
#  '10001.png',
#  '10002.png',
#  '10003.png',
#  '10004.png',
#  '10005.png',
#  '10006.png',
#  '10007.png',
#  '10008.png',
#  '10009.png',
#  '1001.png',
#  '10010.png',
#  '10011.png',
#  '10012.png',
#  '10013.png',
#  '10014.png',
#  '10015.png',
#  '10016.png',
#  '10017.png',
#  '10018.png',
#  '10019.png',
#  '1002.png',
#  '10020.png',
#  '10021.png',
#  '10022.png',
#  '10023.png',
#  '10024.png',
#  '10025.png',
#  '10026.png',
#  '10027.png',
#  '10028.png',
#  '10029.png',
#  '1003.png',
#  '10030.png',
#  '10031.png',
#  '10032.png',
#  '10033.png',
#  '10034.png',
#  '10035.png',
#  '10036.png',
#  '10037.png',
#  '10038.png',
#  '10039.png',
#  '1004.png',
#  '10040.png',
#  '10041.png',
#  '10042.png',
#  '10043.png',
#  '10044.png',
#  '10045.png',
#  '10046.png',
#  '10047.png',
#  '10048.png',
#  '10049.png',
#  '1005.png',
#  '10050.png',
#  '10051.png',
#  '10052.png',
#  '10053.png',
# ...
