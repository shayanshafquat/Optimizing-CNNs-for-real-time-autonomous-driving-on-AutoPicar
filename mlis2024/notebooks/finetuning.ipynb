# %%
import os
import datetime
import random

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# sklearn
from sklearn.model_selection import train_test_split
from utils import get_merged_df

# %%
# tensorflow
import tensorflow as tf
from tensorflow.keras.utils import to_categorical

import keras
from keras.models import Sequential, Model  # V2 is tensorflow.keras.xxxx, V1 is keras.xxx
from keras.layers import Conv2D, MaxPool2D, Dropout, Flatten, Dense, Input, GlobalAveragePooling2D
from keras.models import load_model
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.metrics import F1Score, AUC, CategoricalAccuracy, BinaryAccuracy
from tensorflow.keras.optimizers import RMSprop

print( f'tf.__version__: {tf.__version__}' )
print( f'keras.__version__: {keras.__version__}' )
# Out:
# tf.__version__: 2.15.0
# keras.__version__: 2.15.0

# %%
import cv2
from PIL import Image

# %%
data_dir = 'training_data/training_data'
norm_csv_path = 'training_data/training_norm.csv'
cleaned_df = get_merged_df(data_dir, norm_csv_path)

len(cleaned_df)
# Out:
# 13792

# %%
# angle_labels = cleaned_df['angle'].to_list()
# speed_labels = cleaned_df['speed'].to_list()
# image_paths = cleaned_df['image_path'].to_list()

X_train, X_valid, y_train, y_valid = train_test_split(cleaned_df['image_path'].to_list(), cleaned_df['angle'].to_list(), test_size=0.3)

# X_train, X_valid, angle_train, angle_valid, speed_train, speed_valid = train_test_split(image_paths, angle_labels, speed_labels, test_size=0.3)
print("Training data: %d\nValidation data: %d" % (len(X_train), len(X_valid)))

# print(type(angle_labels))
# Out:
# Training data: 9654
# Validation data: 4138

# %%
def my_imread(image_path):
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    return image

def img_preprocess(image):
    # height, _, _ = image.shape
    # image = image[int(height/2):,:,:]  # remove top half of the image, as it is not relavant for lane following
    # image = cv2.cvtColor(image, cv2.COLOR_RGB2YUV)  # Nvidia model said it is best to use YUV color space
    # image = cv2.GaussianBlur(image, (3,3), 0)
    image = cv2.resize(image, (224,224)) # input image size (200,66) Nvidia model
    # image = image / 255 # normalizing, the processed image becomes black for some reason.  do we need this?
    # image = (image - 127.5) / 127.5
    return image


# fig, axes = plt.subplots(1, 2, figsize=(15, 10))
# image_orig = my_imread(merged_df['image_path'][image_index])
# image_processed = img_preprocess(image_orig)
# axes[0].imshow(image_orig)
# axes[0].set_title("orig")
# axes[1].imshow(image_processed)
# axes[1].set_title("processed")

# %%
def image_data_generator(image_paths, angle_labels, batch_size):
    while True:
        batch_images = []
        batch_angles = []

        for i in range(batch_size):
            random_index = random.randint(0, len(image_paths) - 1)
            image = my_imread(image_paths[random_index])
            angle_label = angle_labels[random_index]
            angle_label *= 16

            image = img_preprocess(image)
            batch_images.append(image)

            angle_one_hot = to_categorical(angle_label, num_classes=17)
            batch_angles.append(angle_one_hot)

        yield( np.asarray(batch_images), np.asarray(batch_angles))

# %%
base_model = keras.applications.Xception(
    weights="imagenet",  # Load weights pre-trained on ImageNet.
    input_shape=(150, 150, 3),
    include_top=False,
)  # Do not include the ImageNet classifier at the top.

# Freeze the base_model
base_model.trainable = False

# Create new model on top
inputs = keras.Input(shape=(150, 150, 3))

# Pre-trained Xception weights requires that input be scaled
# from (0, 255) to a range of (-1., +1.), the rescaling layer
# outputs: `(inputs * scale) + offset`
scale_layer = keras.layers.Rescaling(scale=1 / 127.5, offset=-1)
x = scale_layer(inputs)

# The base model contains batchnorm layers. We want to keep them in inference mode
# when we unfreeze the base model for fine-tuning, so we make sure that the
# base_model is running in inference mode here.
x = base_model(x, training=False)
x = keras.layers.GlobalAveragePooling2D()(x)
x = keras.layers.Dropout(0.2)(x)  # Regularize with dropout
outputs = keras.layers.Dense(1)(x)
model = keras.Model(inputs, outputs)

model.summary(show_trainable=True)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 3s 0us/step
# Model: "model_5"
# ____________________________________________________________________________
#  Layer (type)                Output Shape              Param #   Trainable
# ============================================================================
#  input_7 (InputLayer)        [(None, 150, 150, 3)]     0         Y
#
#  rescaling_5 (Rescaling)     (None, 150, 150, 3)       0         Y
#
#  xception (Functional)       (None, 5, 5, 2048)        2086148   N
#                                                        0
#
#  global_average_pooling2d_5  (None, 2048)              0         Y
#   (GlobalAveragePooling2D)
#
#  dropout_10 (Dropout)        (None, 2048)              0         Y
#
#  dense_10 (Dense)            (None, 1)                 2049      Y
#
# ============================================================================
# Total params: 20863529 (79.59 MB)
# Trainable params: 2049 (8.00 KB)
# Non-trainable params: 20861480 (79.58 MB)
# ____________________________________________________________________________

# %%
def mobile_net_classification_model():
    base_model = keras.applications.MobileNetV2(include_top=False, weights="imagenet", input_shape=(224,224,3))
    base_model.trainable = False
    
    inputs = Input(shape=(224, 224, 3))
    x = tf.keras.layers.Rescaling(1./127.5, offset=-1)(inputs)
    x = base_model(x, training=False)
    x = keras.layers.GlobalAveragePooling2D()(x)

    # Common part of the model
    common = Dense(1024, activation='relu')(x)
    common = Dropout(0.3)(common)

    # Branch for the angle prediction (multi-class classification)
    angle_branch = Dense(512, activation='relu')(common)
    angle_branch = Dropout(0.3)(angle_branch)
    angle_output = Dense(17, activation='softmax', name='angle_output')(angle_branch) # 17 classes for angle

    model = Model(inputs=inputs, outputs=angle_output)
    # Create an RMSprop optimizer with a custom learning rate
    custom_lr = 0.001  # Example custom learning rate
    optimizer = RMSprop(learning_rate=custom_lr)

    model.compile(optimizer=optimizer,
                  loss='categorical_crossentropy',
                  metrics='accuracy')

    return model

# model = nvidia_model()
model = mobile_net_classification_model()
model.summary(show_trainable=True)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.RMSprop` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.RMSprop`.
# Model: "model_9"
# ____________________________________________________________________________
#  Layer (type)                Output Shape              Param #   Trainable
# ============================================================================
#  input_13 (InputLayer)       [(None, 224, 224, 3)]     0         Y
#
#  rescaling_9 (Rescaling)     (None, 224, 224, 3)       0         Y
#
#  mobilenetv2_1.00_224 (Func  (None, 7, 7, 1280)        2257984   N
#  tional)
#
#  global_average_pooling2d_9  (None, 1280)              0         Y
#   (GlobalAveragePooling2D)
#
#  dense_17 (Dense)            (None, 1024)              1311744   Y
#
#  dropout_17 (Dropout)        (None, 1024)              0         Y
#
#  dense_18 (Dense)            (None, 512)               524800    Y
#
#  dropout_18 (Dropout)        (None, 512)               0         Y
#
#  angle_output (Dense)        (None, 17)                8721      Y
#
# ============================================================================
# Total params: 4103249 (15.65 MB)
# Trainable params: 1845265 (7.04 MB)
# Non-trainable params: 2257984 (8.61 MB)
# ____________________________________________________________________________

# %%
model_output_dir = 'models/angle'

# start Tensorboard before model fit, so we can see the epoch tick in Tensorboard
# Jupyter Notebook embedded Tensorboard is a new feature in TF 2.0!!  

# clean up log folder for tensorboard
log_dir_root = f'{model_output_dir}/logs'
#!rm -rf $log_dir_root

tensorboard_callback = TensorBoard(log_dir_root, histogram_freq=1)

# Specify the file path where you want to save the model
filepath = 'models/angle/{epoch:02d}-{val_loss:.2f}'

# Create the ModelCheckpoint callback
model_checkpoint_callback = ModelCheckpoint(
    filepath,
    monitor='val_loss',     # Monitor validation loss
    verbose=1,              # Log a message each time the callback saves the model
    save_best_only=True,    # Only save the model if 'val_loss' has improved
    save_weights_only=False, # Only save the weights of the model
    mode='min',             # 'min' means the monitored quantity should decrease
    save_freq='epoch'       # Check every epoch
)

# %%
history = model.fit(
    image_data_generator(X_train, y_train, batch_size=128),
    steps_per_epoch=len(X_train) // 128,
    epochs=10,
    validation_data = image_data_generator(X_valid, y_valid, batch_size=128),
    validation_steps=len(X_train) // 128,
    verbose=1,
    shuffle=1,
    callbacks=[model_checkpoint_callback, tensorboard_callback]
)
# Out:
# Epoch 1/10
# 75/75 [==============================] - ETA: 0s - loss: 2.2537 - accuracy: 0.2717
# Epoch 1: val_loss improved from inf to 1.80615, saving model to models/angle/01-1.81
# INFO:tensorflow:Assets written to: models/angle/01-1.81/assets
# INFO:tensorflow:Assets written to: models/angle/01-1.81/assets
# 75/75 [==============================] - 169s 2s/step - loss: 2.2537 - accuracy: 0.2717 - val_loss: 1.8062 - val_accuracy: 0.2915
# Epoch 2/10
# 11/75 [===>..........................] - ETA: 1:14 - loss: 1.7200 - accuracy: 0.3125
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 history = model.fit(
#       2     image_data_generator(X_train, y_train, batch_size=128),
#       3     steps_per_epoch=len(X_train) // 128,
#       4     epochs=10,
#       5     validation_data = image_data_generator(X_valid, y_valid, batch_size=128),
#       6     validation_steps=len(X_train) // 128,
#       7     verbose=1,
#       8     shuffle=1,
#       9     callbacks=[model_checkpoint_callback, tensorboard_callback]
#      10 )
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/keras/src/engine/training.py:1807, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1799 with tf.profiler.experimental.Trace(
#    1800     "train",
#    1801     epoch_num=epoch,
#    (...)
#    1804     _r=1,
#    1805 ):
#    1806     callbacks.on_train_batch_begin(step)
# -> 1807     tmp_logs = self.train_function(iterator)
#    1808     if data_handler.should_sync:
#    1809         context.async_wait()
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:832, in Function.__call__(self, *args, **kwds)
#     829 compiler = "xla" if self._jit_compile else "nonXla"
#     831 with OptionalXlaContext(self._jit_compile):
# --> 832   result = self._call(*args, **kwds)
#     834 new_tracing_count = self.experimental_get_tracing_count()
#     835 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:868, in Function._call(self, *args, **kwds)
#     865   self._lock.release()
#     866   # In this case we have created variables on the first call, so we run the
#     867   # defunned version which is guaranteed to never create variables.
# --> 868   return tracing_compilation.call_function(
#     869       args, kwds, self._no_variable_creation_config
#     870   )
#     871 elif self._variable_creation_config is not None:
#     872   # Release the lock early so that multiple threads can perform the call
#     873   # in parallel.
#     874   self._lock.release()
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1323, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1319 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1320 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1321     and executing_eagerly):
#    1322   # No tape is watching; skip to running the function.
# -> 1323   return self._inference_function.call_preflattened(args)
#    1324 forward_backward = self._select_forward_and_backward_functions(
#    1325     args,
#    1326     possible_gradient_type,
#    1327     executing_eagerly)
#    1328 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/tensorflow/python/eager/context.py:1486, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1484 cancellation_context = cancellation.context()
#    1485 if cancellation_context is None:
# -> 1486   outputs = execute.execute(
#    1487       name.decode("utf-8"),
#    1488       num_outputs=num_outputs,
#    1489       inputs=tensor_inputs,
#    1490       attrs=attrs,
#    1491       ctx=self,
#    1492   )
#    1493 else:
#    1494   outputs = execute.execute_with_cancellation(
#    1495       name.decode("utf-8"),
#    1496       num_outputs=num_outputs,
#    (...)
#    1500       cancellation_manager=cancellation_context,
#    1501   )
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
model.trainable = True
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  rescaling_1 (Rescaling)     (None, 224, 224, 3)          0         ['input_2[0][0]']
#
#  Conv1 (Conv2D)              (None, 112, 112, 32)         864       ['rescaling_1[0][0]']
#
#  bn_Conv1 (BatchNormalizati  (None, 112, 112, 32)         128       ['Conv1[0][0]']
#  on)
#
#  Conv1_relu (ReLU)           (None, 112, 112, 32)         0         ['bn_Conv1[0][0]']
#
#  expanded_conv_depthwise (D  (None, 112, 112, 32)         288       ['Conv1_relu[0][0]']
#  epthwiseConv2D)
#
#  expanded_conv_depthwise_BN  (None, 112, 112, 32)         128       ['expanded_conv_depthwise[0][0
#   (BatchNormalization)                                              ]']
#
#  expanded_conv_depthwise_re  (None, 112, 112, 32)         0         ['expanded_conv_depthwise_BN[0
#  lu (ReLU)                                                          ][0]']
#
#  expanded_conv_project (Con  (None, 112, 112, 16)         512       ['expanded_conv_depthwise_relu
#  v2D)                                                               [0][0]']
#
#  expanded_conv_project_BN (  (None, 112, 112, 16)         64        ['expanded_conv_project[0][0]'
#  BatchNormalization)                                                ]
#
#  block_1_expand (Conv2D)     (None, 112, 112, 96)         1536      ['expanded_conv_project_BN[0][
#                                                                     0]']
#
#  block_1_expand_BN (BatchNo  (None, 112, 112, 96)         384       ['block_1_expand[0][0]']
#  rmalization)
#
#  block_1_expand_relu (ReLU)  (None, 112, 112, 96)         0         ['block_1_expand_BN[0][0]']
#
#  block_1_pad (ZeroPadding2D  (None, 113, 113, 96)         0         ['block_1_expand_relu[0][0]']
#  )
#
#  block_1_depthwise (Depthwi  (None, 56, 56, 96)           864       ['block_1_pad[0][0]']
#  seConv2D)
#
#  block_1_depthwise_BN (Batc  (None, 56, 56, 96)           384       ['block_1_depthwise[0][0]']
#  hNormalization)
#
#  block_1_depthwise_relu (Re  (None, 56, 56, 96)           0         ['block_1_depthwise_BN[0][0]']
#  LU)
#
#  block_1_project (Conv2D)    (None, 56, 56, 24)           2304      ['block_1_depthwise_relu[0][0]
#                                                                     ']
#
#  block_1_project_BN (BatchN  (None, 56, 56, 24)           96        ['block_1_project[0][0]']
#  ormalization)
#
#  block_2_expand (Conv2D)     (None, 56, 56, 144)          3456      ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNo  (None, 56, 56, 144)          576       ['block_2_expand[0][0]']
#  rmalization)
#
#  block_2_expand_relu (ReLU)  (None, 56, 56, 144)          0         ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (Depthwi  (None, 56, 56, 144)          1296      ['block_2_expand_relu[0][0]']
#  seConv2D)
#
#  block_2_depthwise_BN (Batc  (None, 56, 56, 144)          576       ['block_2_depthwise[0][0]']
#  hNormalization)
#
#  block_2_depthwise_relu (Re  (None, 56, 56, 144)          0         ['block_2_depthwise_BN[0][0]']
#  LU)
#
#  block_2_project (Conv2D)    (None, 56, 56, 24)           3456      ['block_2_depthwise_relu[0][0]
#                                                                     ']
#
#  block_2_project_BN (BatchN  (None, 56, 56, 24)           96        ['block_2_project[0][0]']
#  ormalization)
#
#  block_2_add (Add)           (None, 56, 56, 24)           0         ['block_1_project_BN[0][0]',
#                                                                      'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)     (None, 56, 56, 144)          3456      ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNo  (None, 56, 56, 144)          576       ['block_3_expand[0][0]']
#  rmalization)
#
#  block_3_expand_relu (ReLU)  (None, 56, 56, 144)          0         ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D  (None, 57, 57, 144)          0         ['block_3_expand_relu[0][0]']
#  )
#
#  block_3_depthwise (Depthwi  (None, 28, 28, 144)          1296      ['block_3_pad[0][0]']
#  seConv2D)
#
#  block_3_depthwise_BN (Batc  (None, 28, 28, 144)          576       ['block_3_depthwise[0][0]']
#  hNormalization)
#
#  block_3_depthwise_relu (Re  (None, 28, 28, 144)          0         ['block_3_depthwise_BN[0][0]']
#  LU)
#
#  block_3_project (Conv2D)    (None, 28, 28, 32)           4608      ['block_3_depthwise_relu[0][0]
#                                                                     ']
#
#  block_3_project_BN (BatchN  (None, 28, 28, 32)           128       ['block_3_project[0][0]']
#  ormalization)
#
#  block_4_expand (Conv2D)     (None, 28, 28, 192)          6144      ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNo  (None, 28, 28, 192)          768       ['block_4_expand[0][0]']
#  rmalization)
#
#  block_4_expand_relu (ReLU)  (None, 28, 28, 192)          0         ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (Depthwi  (None, 28, 28, 192)          1728      ['block_4_expand_relu[0][0]']
#  seConv2D)
#
#  block_4_depthwise_BN (Batc  (None, 28, 28, 192)          768       ['block_4_depthwise[0][0]']
#  hNormalization)
#
#  block_4_depthwise_relu (Re  (None, 28, 28, 192)          0         ['block_4_depthwise_BN[0][0]']
#  LU)
#
#  block_4_project (Conv2D)    (None, 28, 28, 32)           6144      ['block_4_depthwise_relu[0][0]
#                                                                     ']
#
#  block_4_project_BN (BatchN  (None, 28, 28, 32)           128       ['block_4_project[0][0]']
#  ormalization)
#
#  block_4_add (Add)           (None, 28, 28, 32)           0         ['block_3_project_BN[0][0]',
#                                                                      'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)     (None, 28, 28, 192)          6144      ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNo  (None, 28, 28, 192)          768       ['block_5_expand[0][0]']
#  rmalization)
#
#  block_5_expand_relu (ReLU)  (None, 28, 28, 192)          0         ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (Depthwi  (None, 28, 28, 192)          1728      ['block_5_expand_relu[0][0]']
#  seConv2D)
#
#  block_5_depthwise_BN (Batc  (None, 28, 28, 192)          768       ['block_5_depthwise[0][0]']
#  hNormalization)
#
#  block_5_depthwise_relu (Re  (None, 28, 28, 192)          0         ['block_5_depthwise_BN[0][0]']
#  LU)
#
#  block_5_project (Conv2D)    (None, 28, 28, 32)           6144      ['block_5_depthwise_relu[0][0]
#                                                                     ']
#
#  block_5_project_BN (BatchN  (None, 28, 28, 32)           128       ['block_5_project[0][0]']
#  ormalization)
#
#  block_5_add (Add)           (None, 28, 28, 32)           0         ['block_4_add[0][0]',
#                                                                      'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)     (None, 28, 28, 192)          6144      ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNo  (None, 28, 28, 192)          768       ['block_6_expand[0][0]']
#  rmalization)
#
#  block_6_expand_relu (ReLU)  (None, 28, 28, 192)          0         ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D  (None, 29, 29, 192)          0         ['block_6_expand_relu[0][0]']
#  )
#
#  block_6_depthwise (Depthwi  (None, 14, 14, 192)          1728      ['block_6_pad[0][0]']
#  seConv2D)
#
#  block_6_depthwise_BN (Batc  (None, 14, 14, 192)          768       ['block_6_depthwise[0][0]']
#  hNormalization)
#
#  block_6_depthwise_relu (Re  (None, 14, 14, 192)          0         ['block_6_depthwise_BN[0][0]']
#  LU)
#
#  block_6_project (Conv2D)    (None, 14, 14, 64)           12288     ['block_6_depthwise_relu[0][0]
#                                                                     ']
#
#  block_6_project_BN (BatchN  (None, 14, 14, 64)           256       ['block_6_project[0][0]']
#  ormalization)
#
#  block_7_expand (Conv2D)     (None, 14, 14, 384)          24576     ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNo  (None, 14, 14, 384)          1536      ['block_7_expand[0][0]']
#  rmalization)
#
#  block_7_expand_relu (ReLU)  (None, 14, 14, 384)          0         ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (Depthwi  (None, 14, 14, 384)          3456      ['block_7_expand_relu[0][0]']
#  seConv2D)
#
#  block_7_depthwise_BN (Batc  (None, 14, 14, 384)          1536      ['block_7_depthwise[0][0]']
#  hNormalization)
#
#  block_7_depthwise_relu (Re  (None, 14, 14, 384)          0         ['block_7_depthwise_BN[0][0]']
#  LU)
#
#  block_7_project (Conv2D)    (None, 14, 14, 64)           24576     ['block_7_depthwise_relu[0][0]
#                                                                     ']
#
#  block_7_project_BN (BatchN  (None, 14, 14, 64)           256       ['block_7_project[0][0]']
#  ormalization)
#
#  block_7_add (Add)           (None, 14, 14, 64)           0         ['block_6_project_BN[0][0]',
#                                                                      'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)     (None, 14, 14, 384)          24576     ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNo  (None, 14, 14, 384)          1536      ['block_8_expand[0][0]']
#  rmalization)
#
#  block_8_expand_relu (ReLU)  (None, 14, 14, 384)          0         ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (Depthwi  (None, 14, 14, 384)          3456      ['block_8_expand_relu[0][0]']
#  seConv2D)
#
#  block_8_depthwise_BN (Batc  (None, 14, 14, 384)          1536      ['block_8_depthwise[0][0]']
#  hNormalization)
#
#  block_8_depthwise_relu (Re  (None, 14, 14, 384)          0         ['block_8_depthwise_BN[0][0]']
#  LU)
#
#  block_8_project (Conv2D)    (None, 14, 14, 64)           24576     ['block_8_depthwise_relu[0][0]
#                                                                     ']
#
#  block_8_project_BN (BatchN  (None, 14, 14, 64)           256       ['block_8_project[0][0]']
#  ormalization)
#
#  block_8_add (Add)           (None, 14, 14, 64)           0         ['block_7_add[0][0]',
#                                                                      'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)     (None, 14, 14, 384)          24576     ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNo  (None, 14, 14, 384)          1536      ['block_9_expand[0][0]']
#  rmalization)
#
#  block_9_expand_relu (ReLU)  (None, 14, 14, 384)          0         ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (Depthwi  (None, 14, 14, 384)          3456      ['block_9_expand_relu[0][0]']
#  seConv2D)
#
#  block_9_depthwise_BN (Batc  (None, 14, 14, 384)          1536      ['block_9_depthwise[0][0]']
#  hNormalization)
#
#  block_9_depthwise_relu (Re  (None, 14, 14, 384)          0         ['block_9_depthwise_BN[0][0]']
#  LU)
#
#  block_9_project (Conv2D)    (None, 14, 14, 64)           24576     ['block_9_depthwise_relu[0][0]
#                                                                     ']
#
#  block_9_project_BN (BatchN  (None, 14, 14, 64)           256       ['block_9_project[0][0]']
#  ormalization)
#
#  block_9_add (Add)           (None, 14, 14, 64)           0         ['block_8_add[0][0]',
#                                                                      'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)    (None, 14, 14, 384)          24576     ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchN  (None, 14, 14, 384)          1536      ['block_10_expand[0][0]']
#  ormalization)
#
#  block_10_expand_relu (ReLU  (None, 14, 14, 384)          0         ['block_10_expand_BN[0][0]']
#  )
#
#  block_10_depthwise (Depthw  (None, 14, 14, 384)          3456      ['block_10_expand_relu[0][0]']
#  iseConv2D)
#
#  block_10_depthwise_BN (Bat  (None, 14, 14, 384)          1536      ['block_10_depthwise[0][0]']
#  chNormalization)
#
#  block_10_depthwise_relu (R  (None, 14, 14, 384)          0         ['block_10_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_10_project (Conv2D)   (None, 14, 14, 96)           36864     ['block_10_depthwise_relu[0][0
#                                                                     ]']
#
#  block_10_project_BN (Batch  (None, 14, 14, 96)           384       ['block_10_project[0][0]']
#  Normalization)
#
#  block_11_expand (Conv2D)    (None, 14, 14, 576)          55296     ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchN  (None, 14, 14, 576)          2304      ['block_11_expand[0][0]']
#  ormalization)
#
#  block_11_expand_relu (ReLU  (None, 14, 14, 576)          0         ['block_11_expand_BN[0][0]']
#  )
#
#  block_11_depthwise (Depthw  (None, 14, 14, 576)          5184      ['block_11_expand_relu[0][0]']
#  iseConv2D)
#
#  block_11_depthwise_BN (Bat  (None, 14, 14, 576)          2304      ['block_11_depthwise[0][0]']
#  chNormalization)
#
#  block_11_depthwise_relu (R  (None, 14, 14, 576)          0         ['block_11_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_11_project (Conv2D)   (None, 14, 14, 96)           55296     ['block_11_depthwise_relu[0][0
#                                                                     ]']
#
#  block_11_project_BN (Batch  (None, 14, 14, 96)           384       ['block_11_project[0][0]']
#  Normalization)
#
#  block_11_add (Add)          (None, 14, 14, 96)           0         ['block_10_project_BN[0][0]',
#                                                                      'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)    (None, 14, 14, 576)          55296     ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchN  (None, 14, 14, 576)          2304      ['block_12_expand[0][0]']
#  ormalization)
#
#  block_12_expand_relu (ReLU  (None, 14, 14, 576)          0         ['block_12_expand_BN[0][0]']
#  )
#
#  block_12_depthwise (Depthw  (None, 14, 14, 576)          5184      ['block_12_expand_relu[0][0]']
#  iseConv2D)
#
#  block_12_depthwise_BN (Bat  (None, 14, 14, 576)          2304      ['block_12_depthwise[0][0]']
#  chNormalization)
#
#  block_12_depthwise_relu (R  (None, 14, 14, 576)          0         ['block_12_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_12_project (Conv2D)   (None, 14, 14, 96)           55296     ['block_12_depthwise_relu[0][0
#                                                                     ]']
#
#  block_12_project_BN (Batch  (None, 14, 14, 96)           384       ['block_12_project[0][0]']
#  Normalization)
#
#  block_12_add (Add)          (None, 14, 14, 96)           0         ['block_11_add[0][0]',
#                                                                      'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)    (None, 14, 14, 576)          55296     ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchN  (None, 14, 14, 576)          2304      ['block_13_expand[0][0]']
#  ormalization)
#
#  block_13_expand_relu (ReLU  (None, 14, 14, 576)          0         ['block_13_expand_BN[0][0]']
#  )
#
#  block_13_pad (ZeroPadding2  (None, 15, 15, 576)          0         ['block_13_expand_relu[0][0]']
#  D)
#
#  block_13_depthwise (Depthw  (None, 7, 7, 576)            5184      ['block_13_pad[0][0]']
#  iseConv2D)
#
#  block_13_depthwise_BN (Bat  (None, 7, 7, 576)            2304      ['block_13_depthwise[0][0]']
#  chNormalization)
#
#  block_13_depthwise_relu (R  (None, 7, 7, 576)            0         ['block_13_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_13_project (Conv2D)   (None, 7, 7, 160)            92160     ['block_13_depthwise_relu[0][0
#                                                                     ]']
#
#  block_13_project_BN (Batch  (None, 7, 7, 160)            640       ['block_13_project[0][0]']
#  Normalization)
#
#  block_14_expand (Conv2D)    (None, 7, 7, 960)            153600    ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchN  (None, 7, 7, 960)            3840      ['block_14_expand[0][0]']
#  ormalization)
#
#  block_14_expand_relu (ReLU  (None, 7, 7, 960)            0         ['block_14_expand_BN[0][0]']
#  )
#
#  block_14_depthwise (Depthw  (None, 7, 7, 960)            8640      ['block_14_expand_relu[0][0]']
#  iseConv2D)
#
#  block_14_depthwise_BN (Bat  (None, 7, 7, 960)            3840      ['block_14_depthwise[0][0]']
#  chNormalization)
#
#  block_14_depthwise_relu (R  (None, 7, 7, 960)            0         ['block_14_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_14_project (Conv2D)   (None, 7, 7, 160)            153600    ['block_14_depthwise_relu[0][0
#                                                                     ]']
#
#  block_14_project_BN (Batch  (None, 7, 7, 160)            640       ['block_14_project[0][0]']
#  Normalization)
#
#  block_14_add (Add)          (None, 7, 7, 160)            0         ['block_13_project_BN[0][0]',
#                                                                      'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)    (None, 7, 7, 960)            153600    ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchN  (None, 7, 7, 960)            3840      ['block_15_expand[0][0]']
#  ormalization)
#
#  block_15_expand_relu (ReLU  (None, 7, 7, 960)            0         ['block_15_expand_BN[0][0]']
#  )
#
#  block_15_depthwise (Depthw  (None, 7, 7, 960)            8640      ['block_15_expand_relu[0][0]']
#  iseConv2D)
#
#  block_15_depthwise_BN (Bat  (None, 7, 7, 960)            3840      ['block_15_depthwise[0][0]']
#  chNormalization)
#
#  block_15_depthwise_relu (R  (None, 7, 7, 960)            0         ['block_15_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_15_project (Conv2D)   (None, 7, 7, 160)            153600    ['block_15_depthwise_relu[0][0
#                                                                     ]']
#
#  block_15_project_BN (Batch  (None, 7, 7, 160)            640       ['block_15_project[0][0]']
#  Normalization)
#
#  block_15_add (Add)          (None, 7, 7, 160)            0         ['block_14_add[0][0]',
#                                                                      'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)    (None, 7, 7, 960)            153600    ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchN  (None, 7, 7, 960)            3840      ['block_16_expand[0][0]']
#  ormalization)
#
#  block_16_expand_relu (ReLU  (None, 7, 7, 960)            0         ['block_16_expand_BN[0][0]']
#  )
#
#  block_16_depthwise (Depthw  (None, 7, 7, 960)            8640      ['block_16_expand_relu[0][0]']
#  iseConv2D)
#
#  block_16_depthwise_BN (Bat  (None, 7, 7, 960)            3840      ['block_16_depthwise[0][0]']
#  chNormalization)
#
#  block_16_depthwise_relu (R  (None, 7, 7, 960)            0         ['block_16_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_16_project (Conv2D)   (None, 7, 7, 320)            307200    ['block_16_depthwise_relu[0][0
#                                                                     ]']
#
#  block_16_project_BN (Batch  (None, 7, 7, 320)            1280      ['block_16_project[0][0]']
#  Normalization)
#
#  Conv_1 (Conv2D)             (None, 7, 7, 1280)           409600    ['block_16_project_BN[0][0]']
#
#  Conv_1_bn (BatchNormalizat  (None, 7, 7, 1280)           5120      ['Conv_1[0][0]']
#  ion)
#
#  out_relu (ReLU)             (None, 7, 7, 1280)           0         ['Conv_1_bn[0][0]']
#
#  global_average_pooling2d_1  (None, 1280)                 0         ['out_relu[0][0]']
#   (GlobalAveragePooling2D)
#
#  dense_2 (Dense)             (None, 1024)                 1311744   ['global_average_pooling2d_1[0
#                                                                     ][0]']
#
#  dropout_2 (Dropout)         (None, 1024)                 0         ['dense_2[0][0]']
#
#  dense_3 (Dense)             (None, 512)                  524800    ['dropout_2[0][0]']
#
#  dropout_3 (Dropout)         (None, 512)                  0         ['dense_3[0][0]']
#
#  angle_output (Dense)        (None, 17)                   8721      ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 4103249 (15.65 MB)
# Trainable params: 4069137 (15.52 MB)
# Non-trainable params: 34112 (133.25 KB)
# __________________________________________________________________________________________________

# %%
optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.0001)  # Lower learning rate
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Step 3: Continue training the model
history_fine = model.fit(
    image_data_generator(X_train, y_train, batch_size=128),
    steps_per_epoch=len(X_train) // 128,
    epochs=10,  # You can adjust the number of epochs for fine-tuning
    validation_data=image_data_generator(X_valid, y_valid, batch_size=128),
    validation_steps=len(X_valid) // 128,
    verbose=1,
    callbacks=[model_checkpoint_callback]  # Assuming this callback is already defined
)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.RMSprop` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.RMSprop`.
# Epoch 1/10
# 75/75 [==============================] - ETA: 0s - loss: 1.4199 - accuracy: 0.4320
# Epoch 1: val_loss did not improve from 1.42729
# 75/75 [==============================] - 740s 10s/step - loss: 1.4199 - accuracy: 0.4320 - val_loss: 1.7983 - val_accuracy: 0.4062
# Epoch 2/10
# 75/75 [==============================] - ETA: 0s - loss: 1.1333 - accuracy: 0.5450
# Epoch 2: val_loss did not improve from 1.42729
# 75/75 [==============================] - 806s 11s/step - loss: 1.1333 - accuracy: 0.5450 - val_loss: 1.7578 - val_accuracy: 0.3875
# Epoch 3/10
# 75/75 [==============================] - ETA: 0s - loss: 0.9593 - accuracy: 0.6314
# Epoch 3: val_loss did not improve from 1.42729
# 75/75 [==============================] - 837s 11s/step - loss: 0.9593 - accuracy: 0.6314 - val_loss: 2.0642 - val_accuracy: 0.3879
# Epoch 4/10
#  1/75 [..............................] - ETA: 13:05 - loss: 0.7365 - accuracy: 0.7500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 7
#       2 model.compile(optimizer=optimizer,
#       3               loss='categorical_crossentropy',
#       4               metrics=['accuracy'])
#       6 # Step 3: Continue training the model
# ----> 7 history_fine = model.fit(
#       8     image_data_generator(X_train, y_train, batch_size=128),
#       9     steps_per_epoch=len(X_train) // 128,
#      10     epochs=10,  # You can adjust the number of epochs for fine-tuning
#      11     validation_data=image_data_generator(X_valid, y_valid, batch_size=128),
#      12     validation_steps=len(X_valid) // 128,
#      13     verbose=1,
#      14     callbacks=[model_checkpoint_callback]  # Assuming this callback is already defined
#      15 )
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/keras/src/engine/training.py:1807, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1799 with tf.profiler.experimental.Trace(
#    1800     "train",
#    1801     epoch_num=epoch,
#    (...)
#    1804     _r=1,
#    1805 ):
#    1806     callbacks.on_train_batch_begin(step)
# -> 1807     tmp_logs = self.train_function(iterator)
#    1808     if data_handler.should_sync:
#    1809         context.async_wait()
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:832, in Function.__call__(self, *args, **kwds)
#     829 compiler = "xla" if self._jit_compile else "nonXla"
#     831 with OptionalXlaContext(self._jit_compile):
# --> 832   result = self._call(*args, **kwds)
#     834 new_tracing_count = self.experimental_get_tracing_count()
#     835 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:868, in Function._call(self, *args, **kwds)
#     865   self._lock.release()
#     866   # In this case we have created variables on the first call, so we run the
#     867   # defunned version which is guaranteed to never create variables.
# --> 868   return tracing_compilation.call_function(
#     869       args, kwds, self._no_variable_creation_config
#     870   )
#     871 elif self._variable_creation_config is not None:
#     872   # Release the lock early so that multiple threads can perform the call
#     873   # in parallel.
#     874   self._lock.release()
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1323, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1319 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1320 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1321     and executing_eagerly):
#    1322   # No tape is watching; skip to running the function.
# -> 1323   return self._inference_function.call_preflattened(args)
#    1324 forward_backward = self._select_forward_and_backward_functions(
#    1325     args,
#    1326     possible_gradient_type,
#    1327     executing_eagerly)
#    1328 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/tensorflow/python/eager/context.py:1486, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1484 cancellation_context = cancellation.context()
#    1485 if cancellation_context is None:
# -> 1486   outputs = execute.execute(
#    1487       name.decode("utf-8"),
#    1488       num_outputs=num_outputs,
#    1489       inputs=tensor_inputs,
#    1490       attrs=attrs,
#    1491       ctx=self,
#    1492   )
#    1493 else:
#    1494   outputs = execute.execute_with_cancellation(
#    1495       name.decode("utf-8"),
#    1496       num_outputs=num_outputs,
#    (...)
#    1500       cancellation_manager=cancellation_context,
#    1501   )
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Augmentations

# %%
import os
import cv2
import pandas as pd
import shutil
import numpy as np
import random
import tensorflow as tf

# %%
def clear_directory(dir_path):
    if os.path.exists(dir_path):
        shutil.rmtree(dir_path)
    os.makedirs(dir_path, exist_ok=True)

def save_image(image, target_path):
    os.makedirs(os.path.dirname(target_path), exist_ok=True)
    if not os.path.exists(target_path):  # Check if the file has already been copied/augmented
        cv2.imwrite(target_path, image)

# %%
def count_images_in_directories(directory):
    counts = {}
    for class_name in os.listdir(directory):
        class_path = os.path.join(directory, class_name)
        if os.path.isdir(class_path):
            counts[class_name] = len(os.listdir(class_path))
    return counts

def identify_classes_for_augmentation(counts):
    average_count = np.mean(list(counts.values()))
    return [class_name for class_name, count in counts.items() if count < average_count]

# %%
def horizontal_flip(image_path, label):
    image = cv2.imread(image_path)
    augmented = False  # Flag to track if the image has been augmented
    new_label = label
    # Flip the image horizontally
    image = cv2.flip(image, 1)
    augmented = True
    # Adjust the label for the augmented image
    new_label = 180 - label
    return image, augmented, new_label

def tf_adjust_brightness(image):
    return tf.image.random_brightness(image, max_delta=0.2)

def tf_adjust_contrast(image):
    return tf.image.random_contrast(image, lower=0.5, upper=1.5)

# %%
def save_original_images(angle_class_dir, speed_class_dir, image_dir, data):
    # Clear directories first
    clear_directory(angle_class_dir)
    clear_directory(speed_class_dir)

        # Create directories and save original images
    for _, row in data.iterrows():
        source_path = os.path.join(image_dir, f"{int(row['image_id'])}.png")
        for class_dir, class_label in [(angle_class_dir, "angle"), (speed_class_dir, "speed")]:
            target_dir = os.path.join(class_dir, str(row[class_label]))
            os.makedirs(target_dir, exist_ok=True)
            save_image(cv2.imread(source_path), os.path.join(target_dir, f"{int(row['image_id'])}.png"))

    print("Saved original files")

# %%
def augment_images_for_class(row, image_dir, class_dir, class_label):
    source_path = os.path.join(image_dir, f"{int(row['image_id'])}.png")
    original_target_path = os.path.join(class_dir, str(row[class_label]), f"{int(row['image_id'])}.png")
    flipped_image, _, new_label = horizontal_flip(source_path, row[class_label])

    if class_label == "angle":
        flipped_target_path = os.path.join(class_dir, str(new_label), f"{int(row['image_id'])}_flipped.png")
    else:
        flipped_target_path = os.path.join(class_dir, str(row[class_label]), f"{int(row['image_id'])}_flipped.png")
    save_image(flipped_image, flipped_target_path)
    


    # Apply brightness and contrast adjustments based on augmentation_intensity
    # for i in range(int((augmentation_intensity-1)/2)):
    #     if class_label == 'angle':
    #         if random.random() < 0.1:
    #             image_path = flipped_target_path
    #         else:
    #             image_path = original_target_path
    #     else:
    #         if random.random() < 0.5:
    #             image_path = flipped_target_path
    #         else:
    #             image_path = original_target_path

    #     image = tf.io.read_file(image_path)
    #     image = tf.image.decode_png(image, channels=3)
    #     image = tf.cast(image, tf.float32) / 255.0  # Normalize image

    #     bright_image = tf_adjust_brightness(image)
    #     bright_image_path = image_path.replace('.png', f'_bright_{i}.png')
    #     tf.keras.preprocessing.image.save_img(bright_image_path, bright_image.numpy())

    #     contrast_image = tf_adjust_contrast(image)
    #     contrast_image_path = image_path.replace('.png', f'_contrast_{i}.png')
    #     tf.keras.preprocessing.image.save_img(contrast_image_path, contrast_image.numpy())

# %%
def identify_classes_for_augmentation(counts):
    average_count = np.mean(list(counts.values()))
    return [class_name for class_name, count in counts.items() if count < average_count]

# %%
def restructuring_data(load_original, is_augment):
    data = pd.read_csv('training_norm.csv')
    data['angle'] = data['angle'] * 80 + 50
    data.loc[data['speed'] > 1, 'speed'] = 0
    
    image_dir = 'training_data/training_data/'
    angle_class_dir = 'angle_class_data_2'
    speed_class_dir = 'speed_class_data_2'

    if load_original:
        save_original_images(angle_class_dir, speed_class_dir, image_dir, data)

    # Analyze class distribution for angle and speed
    angle_counts = count_images_in_directories(angle_class_dir)
    speed_counts = count_images_in_directories(speed_class_dir)
    max_count_angle = max(angle_counts.values())
    max_count_speed = max(speed_counts.values())
    print(angle_counts, speed_counts)

    angles_for_upscaling = identify_classes_for_augmentation(angle_counts)
    speed_for_upscaling = identify_classes_for_augmentation(speed_counts)
    print(angles_for_upscaling, speed_for_upscaling)

    if is_augment:
    # Apply augmentations based on class imbalance
        for _, row in data.iterrows():
            # angle_aug_intensity = max(1, int(max_count_angle / angle_counts.get(str(row['angle']), max_count_angle)))
            # speed_aug_intensity = max(1, int(max_count_speed / speed_counts.get(str(row['speed']), max_count_speed)))
            if str(180-row['angle']) in angles_for_upscaling:
                print(row["angle"])
                # Augment images for angle class
                augment_images_for_class(row, image_dir, angle_class_dir, "angle")

            if str(row['speed']) in speed_for_upscaling:
                # Augment images for speed class
                augment_images_for_class(row, image_dir, speed_class_dir, "speed")


    print("Data restructuring complete.")

# %%
load_original = False
is_augment = True
restructuring_data(load_original, is_augment)
# Out:
# {'65.0': 1245, '50.0': 95, '75.0': 2220, '115.0': 1147, '130.0': 95, '85.0': 1467, '105.0': 2007, '120.0': 400, '95.0': 1609, '80.0': 2391, '110.0': 2123, '125.0': 93, '90.0': 2046, '100.0': 1963, '60.0': 400, '70.0': 2227, '55.0': 93} {'1.0': 10402, '0.0': 6782}
# ['65.0', '50.0', '115.0', '130.0', '120.0', '125.0', '60.0', '55.0'] ['0.0']
# 115.0
# 60.0
# 120.0
# 115.0
# 120.0
# 115.0
# 115.0
# 115.0
# 115.0
# 115.0
# 120.0
# 60.0
# 115.0
# 120.0
# 125.0
# 125.0
# 120.0
# 60.0
# 120.0
# 120.0
# 115.0
# 50.0
# 60.0
# 115.0
# 115.0
# 120.0
# 115.0
# 65.0
# 115.0
# 120.0
# 115.0
# 120.0
# 115.0
# 115.0
# 115.0
# 125.0
# 120.0
# 125.0
# 125.0
# 115.0
# 65.0
# 115.0
# 55.0
# 115.0
# 115.0
# 115.0
# 120.0
# 115.0
# 125.0
# 115.0
# 115.0
# 55.0
# 115.0
# 115.0
# 115.0
# 60.0
# 115.0
# 115.0
# 115.0
# 115.0
# 115.0
# 125.0
# 120.0
# 130.0
# 60.0
# 115.0
# 115.0
# 115.0
# 115.0
# 115.0
# 60.0
# 115.0
# 120.0
# 115.0
# 125.0
# 115.0
# 60.0
# 60.0
# 120.0
# 115.0
# 115.0
# 120.0
# 115.0
# 120.0
# 115.0
# 115.0
# 115.0
# 115.0
# 120.0
# 120.0
# 60.0
# 115.0
# 115.0
# 115.0
# 115.0
# 115.0
# 120.0
# 115.0
# 115.0
# 115.0
# 115.0
# 115.0
# 115.0
# 115.0
# 115.0
# 115.0
# 50.0
# 50.0
# 120.0
# 55.0
# 115.0
# 115.0
# 120.0
# 115.0
# 115.0
# 115.0
# 115.0
# 115.0
# 115.0
# 125.0
# 115.0
# 65.0
# 120.0
# 55.0
# 115.0
# 125.0
# 115.0
# 120.0
# 50.0
# 65.0
# 120.0
# 60.0
# 65.0
# 115.0
# 115.0
# 115.0
# 115.0
# 115.0
# 115.0
# 120.0
# 115.0
# 115.0
# 120.0
# 115.0
# 120.0
# 120.0
# 115.0
# 120.0
# 115.0
# 115.0
# 125.0
# 120.0
# 115.0
# 120.0
# 115.0
# 120.0
# 115.0
# 115.0
# 115.0
# 115.0
# 65.0
# 115.0
# 115.0
# 115.0
# 120.0
# 120.0
# 125.0
# 115.0
# 115.0
# 115.0
# 115.0
# 115.0
# 115.0
# 115.0
# 115.0
# 115.0
# 115.0
# 115.0
# 120.0
# 115.0
# 60.0
# 120.0
# 115.0
# 115.0
# 115.0
# 60.0
# 115.0
# 55.0
# 115.0
# 115.0
# 130.0
# 115.0
# 115.0
# 115.0
# 120.0
# 115.0
# 115.0
# 115.0
# 115.0
# 120.0
# 60.0
# 115.0
# 115.0
# 115.0
# 115.0
# 115.0
# 120.0
# 115.0
# 50.0
# 120.0
# 115.0
# 60.0
# 130.0
# 120.0
# 115.0
# 115.0
# 115.0
# 115.0
# 115.0
# 115.0
# 115.0
# 120.0
# 115.0
# 115.0
# 115.0
# 115.0
# 55.0
# 115.0
# 50.0
# 125.0
# 115.0
# 115.0
# 115.0
# 115.0
# 120.0
# 115.0
# 60.0
# 60.0
# 115.0
# 120.0
# 115.0
# 125.0
# 115.0
# 115.0
# 115.0
# 115.0
# 115.0
# 115.0
# 65.0
# 115.0
# 65.0
# 50.0
# 115.0
# 120.0
# 115.0
# 60.0
# 50.0
# 120.0
# 60.0
# 130.0
# 115.0
# 120.0
# 115.0
# 115.0
# 130.0
# 120.0
# 115.0
# 115.0
# 115.0
# 115.0
# 120.0
# 125.0
# 115.0
# 115.0
# 115.0
# 115.0
# 115.0
# 115.0
# 115.0
# 50.0
# 115.0
# 120.0
# 120.0
# 115.0
# 115.0
# 115.0
# 115.0
# 115.0
# 55.0
# 60.0
# 115.0
# 115.0
# 50.0
# 115.0
# 115.0
# 65.0
# 115.0
# 115.0
# 120.0
# 115.0
# 125.0
# 65.0
# 120.0
# 115.0
# 60.0
# 65.0
# 115.0
# 115.0
# 115.0
# 65.0
# 115.0
# 115.0
# 60.0
# 65.0
# 120.0
# 115.0
# 50.0
# 115.0
# 115.0
# 115.0
# 115.0
# 125.0
# 115.0
# 115.0
# 115.0
# 115.0
# 115.0
# 60.0
# 115.0
# 50.0
# 115.0
# 115.0
# 115.0
# 50.0
# 115.0
# 115.0
# 55.0
# 130.0
# 125.0
# 55.0
# 120.0
# 115.0
# 115.0
# 115.0
# 115.0
# 120.0
# 115.0
# 115.0
# 115.0
# 50.0
# 60.0
# 115.0
# 115.0
# 115.0
# 120.0
# 115.0
# 115.0
# 115.0
# 115.0
# 115.0
# 115.0
# 115.0
# 115.0
# 130.0
# 115.0
# 55.0
# 50.0
# 125.0
# 115.0
# 115.0
# 115.0
# 115.0
# 115.0
# 115.0
# 115.0
# 115.0
# 115.0
# 115.0
# 60.0
# 115.0
# 60.0
# 65.0
# 115.0
# 115.0
# 120.0
# 115.0
# 125.0
# 115.0
# 115.0
# 115.0
# 115.0
# 120.0
# 115.0
# 115.0
# 115.0
# 60.0
# 120.0
# 115.0
# 115.0
# 65.0
# 115.0
# 115.0
# 115.0
# 115.0
# 60.0
# 115.0
# 115.0
# 120.0
# 65.0
# 130.0
# 115.0
# 115.0
# 50.0
# 115.0
# 50.0
# 115.0
# 120.0
# 115.0
# 120.0
# 115.0
# 115.0
# 115.0
# 120.0
# 120.0
# 120.0
# 120.0
# 115.0
# 115.0
# 115.0
# 115.0
# 125.0
# 115.0
# 115.0
# 115.0
# 115.0
# 120.0
# 115.0
# 120.0
# 115.0
# 120.0
# 115.0
# 130.0
# 115.0
# 120.0
# 115.0
# 115.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[127], line 3
#       1 load_original = False
#       2 is_augment = True
# ----> 3 restructuring_data(load_original, is_augment)
#
# Cell In[126], line 32, in restructuring_data(load_original, is_augment)
#      30     print(row["angle"])
#      31     # Augment images for angle class
# ---> 32     augment_images_for_class(row, image_dir, angle_class_dir, "angle")
#      34 if str(row['speed']) in speed_for_upscaling:
#      35     # Augment images for speed class
#      36     augment_images_for_class(row, image_dir, speed_class_dir, "speed")
#
# Cell In[74], line 4, in augment_images_for_class(row, image_dir, class_dir, class_label)
#       2 source_path = os.path.join(image_dir, f"{int(row['image_id'])}.png")
#       3 original_target_path = os.path.join(class_dir, str(row[class_label]), f"{int(row['image_id'])}.png")
# ----> 4 flipped_image, _, new_label = horizontal_flip(source_path, row[class_label])
#       6 if class_label == "angle":
#       7     flipped_target_path = os.path.join(class_dir, str(new_label), f"{int(row['image_id'])}_flipped.png")
#
# Cell In[20], line 2, in horizontal_flip(image_path, label)
#       1 def horizontal_flip(image_path, label):
# ----> 2     image = cv2.imread(image_path)
#       3     augmented = False  # Flag to track if the image has been augmented
#       4     new_label = label
#
# KeyboardInterrupt:

# %%
angle_class_dir = 'angle_class_data_1'
speed_class_dir = 'speed_class_data_1'
angle_counts = count_images_in_directories(angle_class_dir)
speed_counts = count_images_in_directories(speed_class_dir)

print(angle_counts, speed_counts)
# Out:
# {'65.0': 98, '50.0': 60, '75.0': 213, '115.0': 1147, '130.0': 35, '85.0': 1467, '105.0': 2007, '120.0': 301, '95.0': 1609, '80.0': 428, '110.0': 2123, '125.0': 65, '90.0': 2046, '100.0': 1963, '60.0': 99, '70.0': 104, '55.0': 28} {'1.0': 10402, '0.0': 3391}

# %%
angle_counts = count_images_in_directories(angle_class_dir)
speed_counts = count_images_in_directories(speed_class_dir)

print(angle_counts, speed_counts)
# Out:
# {'65.0': 512, '50.0': 469, '75.0': 727, '115.0': 1291, '130.0': 399, '85.0': 1467, '105.0': 2274, '120.0': 816, '95.0': 1609, '80.0': 814, '110.0': 2263, '125.0': 485, '90.0': 2046, '100.0': 2437, '60.0': 792, '70.0': 532, '55.0': 371} {'1.0': 10402, '0.0': 5202}

# %%
angle_counts = count_images_in_directories(angle_class_dir)
speed_counts = count_images_in_directories(speed_class_dir)

print(angle_counts, speed_counts)

# %%
from tensorflow.keras.models import load_model

# %%
def load_image(
    path,
    image_size,
    num_channels,
    interpolation,
    data_format,
    crop_to_aspect_ratio=False,
    pad_to_aspect_ratio=False,
):
    """Load an image from a path and resize it."""
    img = tf.io.read_file(path)
    img = tf.image.decode_image(
        img, channels=num_channels, expand_animations=False
    )

    if pad_to_aspect_ratio and crop_to_aspect_ratio:
        raise ValueError(
            "Only one of pad_to_aspect_ratio, crop_to_aspect_ratio"
            " can be set to True"
        )

    if crop_to_aspect_ratio:
        from keras.backend import tensorflow as tf_backend

        if data_format == "channels_first":
            img = tf.transpose(img, (2, 0, 1))
        img = image_utils.smart_resize(
            img,
            image_size,
            interpolation=interpolation,
            data_format=data_format,
            backend_module=tf_backend,
        )
    elif pad_to_aspect_ratio:
        img = tf.image.resize_with_pad(
            img, image_size[0], image_size[1], method=interpolation
        )
        if data_format == "channels_first":
            img = tf.transpose(img, (2, 0, 1))
    else:
        img = tf.image.resize(img, image_size, method=interpolation)
        if data_format == "channels_first":
            img = tf.transpose(img, (2, 0, 1))

    if data_format == "channels_last":
        img.set_shape((image_size[0], image_size[1], num_channels))
    else:
        img.set_shape((num_channels, image_size[0], image_size[1]))
    return img

# %%
import tensorflow as tf
import numpy as np

def preprocess_test_image(image_path):
    image = tf.keras.utils.load_img(image_path, target_size=(192,256), color_mode= keep_aspect_ratio=True)  # Resize the image
    im = tf.image.convert_image_dtype(image, tf.float32)
    im = tf.image.resize(im, [192, 192])
    im = tf.expand_dims(im, axis=0)
    return im

# %%
import os

test_directory = 'test_data/test_data'
test_image_paths = [os.path.join(test_directory, fname) for fname in os.listdir(test_directory)]

# %%
angles = [100.0,105.0,110.0,115.0,120.0,125.0,130.0,50.0,55.0,60.0,65.0,70.0,75.0,80.0,85.0,90.0,95.0]

# %%
angle_path = 'models/angle/resnet_best_192_20240328'
speed_path = 'models/speed/resnet_speed_best_20240328'

angle_model = load_model(angle_path)
speed_model = load_model(speed_path)

# %%
def preprocess_angle(image_path):
    img = tf.io.read_file(image_path)
    img = tf.image.decode_image(
        img, channels=3, expand_animations=False
    )
    im = tf.image.resize(img, [192, 192])
    # im = tf.image.grayscale_to_rgb(im)
    im = tf.cast(im, tf.float32)
    im = tf.expand_dims(im, axis=0)
    return im

# %%
def predict_speed(image_path, model):
    image = preprocess_test_image(image_path)
    speed = model.predict(image)[0]
    # Assuming binary classification for speed, adjust as necessary
    speed_pred = np.round(speed[0]).astype(int)
    return speed_pred

# %%
def predict_angle(image_path, model):
    angles = [100.0,105.0,110.0,115.0,120.0,125.0,130.0,50.0,55.0,60.0,65.0,70.0,75.0,80.0,85.0,90.0,95.0]
    image = preprocess_test_image(image_path)

    angle = model.predict(image)
    
    pred_angle = angles[np.argmax(angle)]
    print(pred_angle)
    return (pred_angle-50)/80

# %%
model = tf.keras.models.load_model('models/angle/resnet_best_192_20240328')

test_dir = os.path.abspath('test_data/test_data')
file_list = os.listdir(test_dir)
predictions = []

for file_name in sorted(file_list, key=lambda x: int(x.split('.')[0])):
    img_path = os.path.join(test_dir, file_name)
    image_id = int(file_name.split('.')[0])
    
    angle_pred = predict_angle(img_path, angle_model)
    speed_pred = predict_speed(img_path, speed_model)
    
    print(f"Image ID: {image_id}, Angle: {angle_pred}, Speed: {speed_pred}")
    predictions.append([image_id, angle_pred, speed_pred])
# Out:
# 1/1 [==============================] - 0s 106ms/step
# 120.0
# 1/1 [==============================] - 0s 172ms/step
# Image ID: 1, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 44ms/step
# 120.0
# 1/1 [==============================] - 0s 46ms/step
# Image ID: 2, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 44ms/step
# 120.0
# 1/1 [==============================] - 0s 45ms/step
# Image ID: 3, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 49ms/step
# 120.0
# 1/1 [==============================] - 0s 43ms/step
# Image ID: 4, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 48ms/step
# 120.0
# 1/1 [==============================] - 0s 52ms/step
# Image ID: 5, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 54ms/step
# 120.0
# 1/1 [==============================] - 0s 61ms/step
# Image ID: 6, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 46ms/step
# 120.0
# 1/1 [==============================] - 0s 42ms/step
# Image ID: 7, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 46ms/step
# 110.0
# 1/1 [==============================] - 0s 43ms/step
# Image ID: 8, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 9, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 42ms/step
# 120.0
# 1/1 [==============================] - 0s 45ms/step
# Image ID: 10, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 47ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 11, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 42ms/step
# 110.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 12, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 42ms/step
# Image ID: 13, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 46ms/step
# 110.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 14, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 43ms/step
# 120.0
# 1/1 [==============================] - 0s 45ms/step
# Image ID: 15, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 42ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 16, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 43ms/step
# 120.0
# 1/1 [==============================] - 0s 42ms/step
# Image ID: 17, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 43ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 18, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 42ms/step
# Image ID: 19, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 20, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 39ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 21, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 100ms/step
# 120.0
# 1/1 [==============================] - 0s 53ms/step
# Image ID: 22, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 48ms/step
# 120.0
# 1/1 [==============================] - 0s 39ms/step
# Image ID: 23, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 44ms/step
# 120.0
# 1/1 [==============================] - 0s 44ms/step
# Image ID: 24, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 39ms/step
# 120.0
# 1/1 [==============================] - 0s 43ms/step
# Image ID: 25, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 39ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 26, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 43ms/step
# 110.0
# 1/1 [==============================] - 0s 45ms/step
# Image ID: 27, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 49ms/step
# 120.0
# 1/1 [==============================] - 0s 59ms/step
# Image ID: 28, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 49ms/step
# 120.0
# 1/1 [==============================] - 0s 49ms/step
# Image ID: 29, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 44ms/step
# 120.0
# 1/1 [==============================] - 0s 49ms/step
# Image ID: 30, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 39ms/step
# Image ID: 31, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 43ms/step
# 110.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 32, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 110.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 33, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 38ms/step
# Image ID: 34, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 39ms/step
# 120.0
# 1/1 [==============================] - 0s 39ms/step
# Image ID: 35, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 110.0
# 1/1 [==============================] - 0s 51ms/step
# Image ID: 36, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 48ms/step
# 120.0
# 1/1 [==============================] - 0s 47ms/step
# Image ID: 37, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 44ms/step
# 110.0
# 1/1 [==============================] - 0s 47ms/step
# Image ID: 38, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 45ms/step
# 120.0
# 1/1 [==============================] - 0s 46ms/step
# Image ID: 39, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 43ms/step
# 120.0
# 1/1 [==============================] - 0s 42ms/step
# Image ID: 40, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 44ms/step
# Image ID: 41, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 44ms/step
# Image ID: 42, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 45ms/step
# Image ID: 43, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 42ms/step
# 120.0
# 1/1 [==============================] - 0s 45ms/step
# Image ID: 44, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 82ms/step
# 120.0
# 1/1 [==============================] - 0s 70ms/step
# Image ID: 45, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 243ms/step
# 120.0
# 1/1 [==============================] - 0s 143ms/step
# Image ID: 46, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 55ms/step
# 120.0
# 1/1 [==============================] - 0s 42ms/step
# Image ID: 47, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 48, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 42ms/step
# 120.0
# 1/1 [==============================] - 0s 39ms/step
# Image ID: 49, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 42ms/step
# Image ID: 50, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 42ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 51, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 52, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 39ms/step
# Image ID: 53, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 39ms/step
# Image ID: 54, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 39ms/step
# 110.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 55, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 42ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 56, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 50ms/step
# 120.0
# 1/1 [==============================] - 0s 45ms/step
# Image ID: 57, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 46ms/step
# 120.0
# 1/1 [==============================] - 0s 45ms/step
# Image ID: 58, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 48ms/step
# 120.0
# 1/1 [==============================] - 0s 43ms/step
# Image ID: 59, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 44ms/step
# 120.0
# 1/1 [==============================] - 0s 62ms/step
# Image ID: 60, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 73ms/step
# 120.0
# 1/1 [==============================] - 0s 98ms/step
# Image ID: 61, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 170ms/step
# 120.0
# 1/1 [==============================] - 0s 68ms/step
# Image ID: 62, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 44ms/step
# 110.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 63, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 42ms/step
# 120.0
# 1/1 [==============================] - 0s 42ms/step
# Image ID: 64, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 65, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 110.0
# 1/1 [==============================] - 0s 43ms/step
# Image ID: 66, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 38ms/step
# Image ID: 67, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 39ms/step
# 110.0
# 1/1 [==============================] - 0s 39ms/step
# Image ID: 68, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 69, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 110.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 70, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 43ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 71, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 44ms/step
# Image ID: 72, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 39ms/step
# 120.0
# 1/1 [==============================] - 0s 39ms/step
# Image ID: 73, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 39ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 74, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 75, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 39ms/step
# Image ID: 76, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 39ms/step
# Image ID: 77, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 39ms/step
# 120.0
# 1/1 [==============================] - 0s 39ms/step
# Image ID: 78, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 79, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 42ms/step
# 120.0
# 1/1 [==============================] - 0s 61ms/step
# Image ID: 80, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 91ms/step
# 110.0
# 1/1 [==============================] - 0s 49ms/step
# Image ID: 81, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 39ms/step
# 120.0
# 1/1 [==============================] - 0s 39ms/step
# Image ID: 82, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 39ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 83, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 84, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 85, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 86, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 39ms/step
# 120.0
# 1/1 [==============================] - 0s 39ms/step
# Image ID: 87, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 88, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 89, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 39ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 90, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 91, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 92, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 42ms/step
# 120.0
# 1/1 [==============================] - 0s 50ms/step
# Image ID: 93, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 117ms/step
# 120.0
# 1/1 [==============================] - 0s 112ms/step
# Image ID: 94, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 56ms/step
# 120.0
# 1/1 [==============================] - 0s 68ms/step
# Image ID: 95, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 116ms/step
# 120.0
# 1/1 [==============================] - 0s 49ms/step
# Image ID: 96, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 43ms/step
# Image ID: 97, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 52ms/step
# 120.0
# 1/1 [==============================] - 0s 50ms/step
# Image ID: 98, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 53ms/step
# 120.0
# 1/1 [==============================] - 0s 57ms/step
# Image ID: 99, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 47ms/step
# 120.0
# 1/1 [==============================] - 0s 46ms/step
# Image ID: 100, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 45ms/step
# 120.0
# 1/1 [==============================] - 0s 45ms/step
# Image ID: 101, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 102, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 65ms/step
# Image ID: 103, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 79ms/step
# 120.0
# 1/1 [==============================] - 0s 143ms/step
# Image ID: 104, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 215ms/step
# 120.0
# 1/1 [==============================] - 0s 153ms/step
# Image ID: 105, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 113ms/step
# 120.0
# 1/1 [==============================] - 0s 54ms/step
# Image ID: 106, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 48ms/step
# 120.0
# 1/1 [==============================] - 0s 105ms/step
# Image ID: 107, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 97ms/step
# 110.0
# 1/1 [==============================] - 0s 48ms/step
# Image ID: 108, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 42ms/step
# 110.0
# 1/1 [==============================] - 0s 42ms/step
# Image ID: 109, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 45ms/step
# 120.0
# 1/1 [==============================] - 0s 42ms/step
# Image ID: 110, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 59ms/step
# Image ID: 111, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 44ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 112, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 42ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 113, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 46ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 114, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 45ms/step
# Image ID: 115, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 44ms/step
# 120.0
# 1/1 [==============================] - 0s 48ms/step
# Image ID: 116, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 43ms/step
# Image ID: 117, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 47ms/step
# Image ID: 118, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 104ms/step
# 120.0
# 1/1 [==============================] - 0s 74ms/step
# Image ID: 119, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 67ms/step
# 120.0
# 1/1 [==============================] - 0s 66ms/step
# Image ID: 120, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 53ms/step
# 120.0
# 1/1 [==============================] - 0s 45ms/step
# Image ID: 121, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 42ms/step
# 110.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 122, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 43ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 123, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 42ms/step
# 120.0
# 1/1 [==============================] - 0s 46ms/step
# Image ID: 124, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 44ms/step
# 120.0
# 1/1 [==============================] - 0s 45ms/step
# Image ID: 125, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 48ms/step
# 120.0
# 1/1 [==============================] - 0s 64ms/step
# Image ID: 126, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 83ms/step
# 120.0
# 1/1 [==============================] - 0s 80ms/step
# Image ID: 127, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 54ms/step
# 120.0
# 1/1 [==============================] - 0s 46ms/step
# Image ID: 128, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 45ms/step
# 120.0
# 1/1 [==============================] - 0s 46ms/step
# Image ID: 129, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 53ms/step
# 120.0
# 1/1 [==============================] - 0s 50ms/step
# Image ID: 130, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 46ms/step
# 120.0
# 1/1 [==============================] - 0s 48ms/step
# Image ID: 131, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 53ms/step
# 120.0
# 1/1 [==============================] - 0s 95ms/step
# Image ID: 132, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 130ms/step
# 110.0
# 1/1 [==============================] - 0s 69ms/step
# Image ID: 133, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 48ms/step
# 110.0
# 1/1 [==============================] - 0s 42ms/step
# Image ID: 134, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 48ms/step
# 110.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 135, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 46ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 136, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 52ms/step
# 120.0
# 1/1 [==============================] - 0s 46ms/step
# Image ID: 137, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 54ms/step
# 120.0
# 1/1 [==============================] - 0s 64ms/step
# Image ID: 138, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 47ms/step
# 115.0
# 1/1 [==============================] - 0s 43ms/step
# Image ID: 139, Angle: 0.8125, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 110.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 140, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 49ms/step
# 120.0
# 1/1 [==============================] - 0s 48ms/step
# Image ID: 141, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 42ms/step
# 120.0
# 1/1 [==============================] - 0s 45ms/step
# Image ID: 142, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 42ms/step
# 110.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 143, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 50ms/step
# 120.0
# 1/1 [==============================] - 0s 117ms/step
# Image ID: 144, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 115ms/step
# 120.0
# 1/1 [==============================] - 0s 77ms/step
# Image ID: 145, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 55ms/step
# 110.0
# 1/1 [==============================] - 0s 42ms/step
# Image ID: 146, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 44ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 147, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 56ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 148, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 42ms/step
# 120.0
# 1/1 [==============================] - 0s 51ms/step
# Image ID: 149, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 51ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 150, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 110.0
# 1/1 [==============================] - 0s 43ms/step
# Image ID: 151, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 39ms/step
# Image ID: 152, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 43ms/step
# 120.0
# 1/1 [==============================] - 0s 144ms/step
# Image ID: 153, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 112ms/step
# 120.0
# 1/1 [==============================] - 0s 50ms/step
# Image ID: 154, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 44ms/step
# 120.0
# 1/1 [==============================] - 0s 43ms/step
# Image ID: 155, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 45ms/step
# 120.0
# 1/1 [==============================] - 0s 42ms/step
# Image ID: 156, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 48ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 157, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 44ms/step
# 120.0
# 1/1 [==============================] - 0s 64ms/step
# Image ID: 158, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 141ms/step
# 120.0
# 1/1 [==============================] - 0s 213ms/step
# Image ID: 159, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 173ms/step
# 120.0
# 1/1 [==============================] - 0s 110ms/step
# Image ID: 160, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 150ms/step
# 120.0
# 1/1 [==============================] - 0s 74ms/step
# Image ID: 161, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 54ms/step
# 120.0
# 1/1 [==============================] - 0s 48ms/step
# Image ID: 162, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 42ms/step
# 110.0
# 1/1 [==============================] - 0s 43ms/step
# Image ID: 163, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 101ms/step
# 110.0
# 1/1 [==============================] - 0s 125ms/step
# Image ID: 164, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 65ms/step
# 120.0
# 1/1 [==============================] - 0s 47ms/step
# Image ID: 165, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 54ms/step
# 120.0
# 1/1 [==============================] - 0s 46ms/step
# Image ID: 166, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 167, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 67ms/step
# 120.0
# 1/1 [==============================] - 0s 45ms/step
# Image ID: 168, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 42ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 169, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 42ms/step
# Image ID: 170, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 171, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 110.0
# 1/1 [==============================] - 0s 44ms/step
# Image ID: 172, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 173, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 174, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 175, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 43ms/step
# Image ID: 176, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 110.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 177, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 43ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 178, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 179, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 180, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 44ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 181, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 110.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 182, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 123ms/step
# 120.0
# 1/1 [==============================] - 0s 109ms/step
# Image ID: 183, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 71ms/step
# 120.0
# 1/1 [==============================] - 0s 67ms/step
# Image ID: 184, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 50ms/step
# 120.0
# 1/1 [==============================] - 0s 44ms/step
# Image ID: 185, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 44ms/step
# 110.0
# 1/1 [==============================] - 0s 48ms/step
# Image ID: 186, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 42ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 187, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 44ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 188, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 42ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 189, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 43ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 190, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 42ms/step
# 120.0
# 1/1 [==============================] - 0s 39ms/step
# Image ID: 191, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 44ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 192, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 39ms/step
# Image ID: 193, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 44ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 194, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 104ms/step
# 120.0
# 1/1 [==============================] - 0s 60ms/step
# Image ID: 195, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 196, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 44ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 197, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 44ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 198, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 110.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 199, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 46ms/step
# 120.0
# 1/1 [==============================] - 0s 42ms/step
# Image ID: 200, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 201, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 110.0
# 1/1 [==============================] - 0s 52ms/step
# Image ID: 202, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 203, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 115.0
# 1/1 [==============================] - 0s 43ms/step
# Image ID: 204, Angle: 0.8125, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 113ms/step
# Image ID: 205, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 67ms/step
# 120.0
# 1/1 [==============================] - 0s 151ms/step
# Image ID: 206, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 387ms/step
# 120.0
# 1/1 [==============================] - 0s 164ms/step
# Image ID: 207, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 61ms/step
# 120.0
# 1/1 [==============================] - 0s 44ms/step
# Image ID: 208, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 54ms/step
# 120.0
# 1/1 [==============================] - 0s 78ms/step
# Image ID: 209, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 66ms/step
# 120.0
# 1/1 [==============================] - 0s 107ms/step
# Image ID: 210, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 324ms/step
# 120.0
# 1/1 [==============================] - 0s 127ms/step
# Image ID: 211, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 55ms/step
# 120.0
# 1/1 [==============================] - 0s 48ms/step
# Image ID: 212, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 42ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 213, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 44ms/step
# Image ID: 214, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 45ms/step
# 120.0
# 1/1 [==============================] - 0s 65ms/step
# Image ID: 215, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 54ms/step
# 110.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 216, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 42ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 217, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 124ms/step
# 120.0
# 1/1 [==============================] - 0s 57ms/step
# Image ID: 218, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 47ms/step
# 120.0
# 1/1 [==============================] - 0s 44ms/step
# Image ID: 219, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 42ms/step
# 120.0
# 1/1 [==============================] - 0s 39ms/step
# Image ID: 220, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 221, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 222, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 110.0
# 1/1 [==============================] - 0s 46ms/step
# Image ID: 223, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 224, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 43ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 225, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 110.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 226, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 42ms/step
# Image ID: 227, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 110.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 228, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 229, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 171ms/step
# Image ID: 230, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 42ms/step
# 120.0
# 1/1 [==============================] - 0s 46ms/step
# Image ID: 231, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 46ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 232, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 233, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 234, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 42ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 235, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 44ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 236, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 237, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 238, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 47ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 239, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 42ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 240, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 44ms/step
# 120.0
# 1/1 [==============================] - 0s 76ms/step
# Image ID: 241, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 242, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 243, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 42ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 244, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 245, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 246, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 42ms/step
# 120.0
# 1/1 [==============================] - 0s 46ms/step
# Image ID: 247, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 248, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 110.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 249, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 110.0
# 1/1 [==============================] - 0s 64ms/step
# Image ID: 250, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 48ms/step
# 120.0
# 1/1 [==============================] - 0s 45ms/step
# Image ID: 251, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 60ms/step
# 120.0
# 1/1 [==============================] - 0s 52ms/step
# Image ID: 252, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 51ms/step
# 120.0
# 1/1 [==============================] - 0s 51ms/step
# Image ID: 253, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 45ms/step
# 110.0
# 1/1 [==============================] - 0s 45ms/step
# Image ID: 254, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 255, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 110.0
# 1/1 [==============================] - 0s 39ms/step
# Image ID: 256, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 42ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 257, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 42ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 258, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 42ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 259, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 42ms/step
# Image ID: 260, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 110.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 261, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 42ms/step
# Image ID: 262, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 69ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 263, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 39ms/step
# Image ID: 264, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 39ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 265, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 42ms/step
# 110.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 266, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 267, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 268, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 110.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 269, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 270, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 110.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 271, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 272, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 273, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 62ms/step
# 120.0
# 1/1 [==============================] - 0s 83ms/step
# Image ID: 274, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 46ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 275, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 276, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 39ms/step
# Image ID: 277, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 278, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 279, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 42ms/step
# 120.0
# 1/1 [==============================] - 0s 46ms/step
# Image ID: 280, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 110.0
# 1/1 [==============================] - 0s 59ms/step
# Image ID: 281, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 194ms/step
# 110.0
# 1/1 [==============================] - 0s 329ms/step
# Image ID: 282, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 97ms/step
# 120.0
# 1/1 [==============================] - 0s 130ms/step
# Image ID: 283, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 218ms/step
# 110.0
# 1/1 [==============================] - 0s 84ms/step
# Image ID: 284, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 48ms/step
# 120.0
# 1/1 [==============================] - 0s 43ms/step
# Image ID: 285, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 45ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 286, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 39ms/step
# 120.0
# 1/1 [==============================] - 0s 44ms/step
# Image ID: 287, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 288, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 289, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 290, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 291, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 110.0
# 1/1 [==============================] - 0s 54ms/step
# Image ID: 292, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 293, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 42ms/step
# 110.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 294, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 54ms/step
# 120.0
# 1/1 [==============================] - 0s 49ms/step
# Image ID: 295, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 46ms/step
# 120.0
# 1/1 [==============================] - 0s 42ms/step
# Image ID: 296, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 43ms/step
# 120.0
# 1/1 [==============================] - 0s 42ms/step
# Image ID: 297, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 52ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 298, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 45ms/step
# Image ID: 299, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 99ms/step
# 120.0
# 1/1 [==============================] - 0s 65ms/step
# Image ID: 300, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 53ms/step
# 120.0
# 1/1 [==============================] - 0s 50ms/step
# Image ID: 301, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 46ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 302, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 303, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 304, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 53ms/step
# Image ID: 305, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 306, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 110.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 307, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 53ms/step
# 120.0
# 1/1 [==============================] - 0s 53ms/step
# Image ID: 308, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 65ms/step
# 115.0
# 1/1 [==============================] - 0s 57ms/step
# Image ID: 309, Angle: 0.8125, Speed: 1
# 1/1 [==============================] - 0s 47ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 310, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 43ms/step
# Image ID: 311, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 312, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 43ms/step
# 120.0
# 1/1 [==============================] - 0s 44ms/step
# Image ID: 313, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 42ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 314, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 315, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 61ms/step
# 120.0
# 1/1 [==============================] - 0s 43ms/step
# Image ID: 316, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 39ms/step
# 110.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 317, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 318, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 42ms/step
# Image ID: 319, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 42ms/step
# 120.0
# 1/1 [==============================] - 0s 44ms/step
# Image ID: 320, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 45ms/step
# 120.0
# 1/1 [==============================] - 0s 46ms/step
# Image ID: 321, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 52ms/step
# 115.0
# 1/1 [==============================] - 0s 148ms/step
# Image ID: 322, Angle: 0.8125, Speed: 1
# 1/1 [==============================] - 0s 60ms/step
# 120.0
# 1/1 [==============================] - 0s 43ms/step
# Image ID: 323, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 39ms/step
# Image ID: 324, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 325, Angle: 0.875, Speed: 1
# ...
# 120.0
# 1/1 [==============================] - 0s 51ms/step
# Image ID: 913, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 38ms/step
# Image ID: 914, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 39ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 915, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 916, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 53ms/step
# Image ID: 917, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 918, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 39ms/step
# 120.0
# 1/1 [==============================] - 0s 38ms/step
# Image ID: 919, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 920, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 53ms/step
# Image ID: 921, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 39ms/step
# 110.0
# 1/1 [==============================] - 0s 38ms/step
# Image ID: 922, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 39ms/step
# 120.0
# 1/1 [==============================] - 0s 39ms/step
# Image ID: 923, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 43ms/step
# 120.0
# 1/1 [==============================] - 0s 68ms/step
# Image ID: 924, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 46ms/step
# 110.0
# 1/1 [==============================] - 0s 80ms/step
# Image ID: 925, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 46ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 926, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 50ms/step
# 120.0
# 1/1 [==============================] - 0s 47ms/step
# Image ID: 927, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 42ms/step
# 120.0
# 1/1 [==============================] - 0s 116ms/step
# Image ID: 928, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 46ms/step
# 120.0
# 1/1 [==============================] - 0s 125ms/step
# Image ID: 929, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 153ms/step
# 120.0
# 1/1 [==============================] - 0s 55ms/step
# Image ID: 930, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 46ms/step
# 120.0
# 1/1 [==============================] - 0s 49ms/step
# Image ID: 931, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 110.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 932, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 126ms/step
# 120.0
# 1/1 [==============================] - 0s 97ms/step
# Image ID: 933, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 49ms/step
# 120.0
# 1/1 [==============================] - 0s 42ms/step
# Image ID: 934, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 48ms/step
# 120.0
# 1/1 [==============================] - 0s 51ms/step
# Image ID: 935, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 44ms/step
# Image ID: 936, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 126ms/step
# 120.0
# 1/1 [==============================] - 0s 104ms/step
# Image ID: 937, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 63ms/step
# 120.0
# 1/1 [==============================] - 0s 51ms/step
# Image ID: 938, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 52ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 939, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 42ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 940, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 43ms/step
# 120.0
# 1/1 [==============================] - 0s 169ms/step
# Image ID: 941, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 132ms/step
# 120.0
# 1/1 [==============================] - 0s 51ms/step
# Image ID: 942, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 55ms/step
# 120.0
# 1/1 [==============================] - 0s 43ms/step
# Image ID: 943, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 944, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 135ms/step
# Image ID: 945, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 174ms/step
# 120.0
# 1/1 [==============================] - 0s 65ms/step
# Image ID: 946, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 48ms/step
# 120.0
# 1/1 [==============================] - 0s 43ms/step
# Image ID: 947, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 43ms/step
# Image ID: 948, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 42ms/step
# 120.0
# 1/1 [==============================] - 0s 210ms/step
# Image ID: 949, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 156ms/step
# 120.0
# 1/1 [==============================] - 0s 46ms/step
# Image ID: 950, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 45ms/step
# Image ID: 951, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 952, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 112ms/step
# Image ID: 953, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 59ms/step
# 110.0
# 1/1 [==============================] - 0s 45ms/step
# Image ID: 954, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 44ms/step
# 115.0
# 1/1 [==============================] - 0s 49ms/step
# Image ID: 955, Angle: 0.8125, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 956, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 110.0
# 1/1 [==============================] - 0s 65ms/step
# Image ID: 957, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 46ms/step
# 120.0
# 1/1 [==============================] - 0s 39ms/step
# Image ID: 958, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 39ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 959, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 39ms/step
# 120.0
# 1/1 [==============================] - 0s 39ms/step
# Image ID: 960, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 39ms/step
# 120.0
# 1/1 [==============================] - 0s 49ms/step
# Image ID: 961, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 962, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 42ms/step
# 120.0
# 1/1 [==============================] - 0s 44ms/step
# Image ID: 963, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 39ms/step
# 120.0
# 1/1 [==============================] - 0s 39ms/step
# Image ID: 964, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 65ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 965, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 38ms/step
# 120.0
# 1/1 [==============================] - 0s 39ms/step
# Image ID: 966, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 42ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 967, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 39ms/step
# 120.0
# 1/1 [==============================] - 0s 65ms/step
# Image ID: 968, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 110.0
# 1/1 [==============================] - 0s 39ms/step
# Image ID: 969, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 39ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 970, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 39ms/step
# 110.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 971, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 65ms/step
# 120.0
# 1/1 [==============================] - 0s 61ms/step
# Image ID: 972, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 45ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 973, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 974, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 39ms/step
# 120.0
# 1/1 [==============================] - 0s 164ms/step
# Image ID: 975, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 146ms/step
# 110.0
# 1/1 [==============================] - 0s 52ms/step
# Image ID: 976, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 43ms/step
# Image ID: 977, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 43ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 978, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 109ms/step
# 110.0
# 1/1 [==============================] - 0s 99ms/step
# Image ID: 979, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 77ms/step
# 120.0
# 1/1 [==============================] - 0s 51ms/step
# Image ID: 980, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 39ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 981, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 39ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 982, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 63ms/step
# 110.0
# 1/1 [==============================] - 0s 44ms/step
# Image ID: 983, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 110.0
# 1/1 [==============================] - 0s 39ms/step
# Image ID: 984, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 48ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 985, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 44ms/step
# 115.0
# 1/1 [==============================] - 0s 364ms/step
# Image ID: 986, Angle: 0.8125, Speed: 1
# 1/1 [==============================] - 0s 87ms/step
# 120.0
# 1/1 [==============================] - 0s 44ms/step
# Image ID: 987, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 38ms/step
# 120.0
# 1/1 [==============================] - 0s 39ms/step
# Image ID: 988, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 41ms/step
# 120.0
# 1/1 [==============================] - 0s 39ms/step
# Image ID: 989, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 68ms/step
# 120.0
# 1/1 [==============================] - 0s 45ms/step
# Image ID: 990, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 39ms/step
# Image ID: 991, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 39ms/step
# 120.0
# 1/1 [==============================] - 0s 39ms/step
# Image ID: 992, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 38ms/step
# 120.0
# 1/1 [==============================] - 0s 55ms/step
# Image ID: 993, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 44ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 994, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 995, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 42ms/step
# 120.0
# 1/1 [==============================] - 0s 45ms/step
# Image ID: 996, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 185ms/step
# 120.0
# 1/1 [==============================] - 0s 88ms/step
# Image ID: 997, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 47ms/step
# 120.0
# 1/1 [==============================] - 0s 83ms/step
# Image ID: 998, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 44ms/step
# 120.0
# 1/1 [==============================] - 0s 45ms/step
# Image ID: 999, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 39ms/step
# Image ID: 1000, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 201ms/step
# 120.0
# 1/1 [==============================] - 0s 98ms/step
# Image ID: 1001, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 72ms/step
# 115.0
# 1/1 [==============================] - 0s 48ms/step
# Image ID: 1002, Angle: 0.8125, Speed: 1
# 1/1 [==============================] - 0s 39ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 1003, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 85ms/step
# Image ID: 1004, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 59ms/step
# 110.0
# 1/1 [==============================] - 0s 49ms/step
# Image ID: 1005, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 38ms/step
# 120.0
# 1/1 [==============================] - 0s 38ms/step
# Image ID: 1006, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 42ms/step
# 120.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 1007, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 63ms/step
# 120.0
# 1/1 [==============================] - 0s 61ms/step
# Image ID: 1008, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 77ms/step
# 120.0
# 1/1 [==============================] - 0s 49ms/step
# Image ID: 1009, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 39ms/step
# Image ID: 1010, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 39ms/step
# 120.0
# 1/1 [==============================] - 0s 39ms/step
# Image ID: 1011, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 64ms/step
# 120.0
# 1/1 [==============================] - 0s 45ms/step
# Image ID: 1012, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 42ms/step
# Image ID: 1013, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 45ms/step
# 120.0
# 1/1 [==============================] - 0s 42ms/step
# Image ID: 1014, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 39ms/step
# 115.0
# 1/1 [==============================] - 0s 54ms/step
# Image ID: 1015, Angle: 0.8125, Speed: 1
# 1/1 [==============================] - 0s 43ms/step
# 120.0
# 1/1 [==============================] - 0s 39ms/step
# Image ID: 1016, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 38ms/step
# 110.0
# 1/1 [==============================] - 0s 41ms/step
# Image ID: 1017, Angle: 0.75, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 40ms/step
# Image ID: 1018, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 60ms/step
# Image ID: 1019, Angle: 0.875, Speed: 1
# 1/1 [==============================] - 0s 40ms/step
# 120.0
# 1/1 [==============================] - 0s 38ms/step
# Image ID: 1020, Angle: 0.875, Speed: 1

# %%
df_pred = pd.DataFrame(predictions, columns=['image_id', 'speed', 'angle'])
df_pred.to_csv(f'submission_check.csv', index=False)
# Out:
# [['test_data/test_data/348.png', 100.0],
#  ['test_data/test_data/412.png', 120.0],
#  ['test_data/test_data/374.png', 95.0],
#  ['test_data/test_data/360.png', 120.0],
#  ['test_data/test_data/406.png', 100.0],
#  ['test_data/test_data/638.png', 95.0],
#  ['test_data/test_data/176.png', 95.0],
#  ['test_data/test_data/88.png', 95.0],
#  ['test_data/test_data/610.png', 100.0],
#  ['test_data/test_data/604.png', 100.0],
#  ['test_data/test_data/162.png', 95.0],
#  ['test_data/test_data/189.png', 100.0],
#  ['test_data/test_data/837.png', 95.0],
#  ['test_data/test_data/77.png', 115.0],
#  ['test_data/test_data/823.png', 95.0],
#  ['test_data/test_data/63.png', 110.0],
#  ['test_data/test_data/980.png', 120.0],
#  ['test_data/test_data/758.png', 95.0],
#  ['test_data/test_data/994.png', 100.0],
#  ['test_data/test_data/764.png', 95.0],
#  ['test_data/test_data/770.png', 95.0],
#  ['test_data/test_data/943.png', 100.0],
#  ['test_data/test_data/957.png', 100.0],
#  ['test_data/test_data/228.png', 110.0],
#  ['test_data/test_data/566.png', 95.0],
#  ['test_data/test_data/200.png', 95.0],
#  ['test_data/test_data/214.png', 95.0],
#  ['test_data/test_data/572.png', 95.0],
#  ['test_data/test_data/599.png', 100.0],
#  ['test_data/test_data/1019.png', 120.0],
#  ['test_data/test_data/1018.png', 95.0],
#  ['test_data/test_data/598.png', 95.0],
#  ['test_data/test_data/215.png', 110.0],
#  ['test_data/test_data/573.png', 115.0],
#  ['test_data/test_data/567.png', 95.0],
#  ['test_data/test_data/201.png', 95.0],
#  ['test_data/test_data/229.png', 95.0],
#  ['test_data/test_data/956.png', 95.0],
#  ['test_data/test_data/942.png', 110.0],
#  ['test_data/test_data/771.png', 120.0],
#  ['test_data/test_data/765.png', 100.0],
#  ['test_data/test_data/995.png', 95.0],
#  ['test_data/test_data/759.png', 75.0],
#  ['test_data/test_data/981.png', 75.0],
#  ['test_data/test_data/62.png', 95.0],
#  ['test_data/test_data/822.png', 110.0],
#  ['test_data/test_data/188.png', 95.0],
#  ['test_data/test_data/76.png', 100.0],
#  ['test_data/test_data/836.png', 95.0],
#  ['test_data/test_data/605.png', 95.0],
#  ['test_data/test_data/163.png', 110.0],
#  ['test_data/test_data/177.png', 100.0],
#  ['test_data/test_data/611.png', 120.0],
#  ['test_data/test_data/89.png', 95.0],
#  ['test_data/test_data/639.png', 95.0],
#  ['test_data/test_data/361.png', 105.0],
#  ['test_data/test_data/407.png', 100.0],
#  ['test_data/test_data/413.png', 105.0],
#  ['test_data/test_data/375.png', 95.0],
#  ['test_data/test_data/349.png', 100.0],
#  ['test_data/test_data/439.png', 110.0],
#  ['test_data/test_data/405.png', 100.0],
#  ['test_data/test_data/363.png', 95.0],
#  ['test_data/test_data/377.png', 100.0],
#  ['test_data/test_data/411.png', 110.0],
#  ['test_data/test_data/388.png', 75.0],
#  ['test_data/test_data/149.png', 95.0],
#  ['test_data/test_data/161.png', 110.0],
#  ['test_data/test_data/607.png', 120.0],
#  ['test_data/test_data/613.png', 100.0],
#  ['test_data/test_data/175.png', 95.0],
#  ['test_data/test_data/820.png', 100.0],
#  ['test_data/test_data/60.png', 110.0],
#  ['test_data/test_data/834.png', 120.0],
#  ['test_data/test_data/74.png', 100.0],
#  ['test_data/test_data/808.png', 95.0],
#  ['test_data/test_data/48.png', 100.0],
#  ['test_data/test_data/997.png', 120.0],
#  ['test_data/test_data/983.png', 100.0],
#  ['test_data/test_data/773.png', 105.0],
#  ['test_data/test_data/767.png', 100.0],
#  ['test_data/test_data/954.png', 100.0],
#  ['test_data/test_data/798.png', 110.0],
#  ['test_data/test_data/940.png', 95.0],
#  ['test_data/test_data/968.png', 100.0],
#  ['test_data/test_data/559.png', 100.0],
#  ['test_data/test_data/571.png', 100.0],
#  ['test_data/test_data/217.png', 110.0],
#  ['test_data/test_data/203.png', 100.0],
#  ['test_data/test_data/565.png', 110.0],
#  ['test_data/test_data/202.png', 110.0],
#  ['test_data/test_data/564.png', 100.0],
#  ['test_data/test_data/570.png', 95.0],
#  ['test_data/test_data/216.png', 100.0],
#  ['test_data/test_data/558.png', 95.0],
#  ['test_data/test_data/969.png', 100.0],
#  ['test_data/test_data/941.png', 95.0],
#  ['test_data/test_data/799.png', 95.0],
#  ['test_data/test_data/955.png', 95.0],
#  ['test_data/test_data/766.png', 100.0],
#  ['test_data/test_data/772.png', 75.0],
#  ['test_data/test_data/982.png', 95.0],
#  ['test_data/test_data/996.png', 105.0],
#  ['test_data/test_data/49.png', 120.0],
#  ['test_data/test_data/809.png', 105.0],
#  ['test_data/test_data/75.png', 100.0],
#  ['test_data/test_data/835.png', 110.0],
#  ['test_data/test_data/61.png', 105.0],
#  ['test_data/test_data/821.png', 95.0],
#  ['test_data/test_data/612.png', 110.0],
#  ['test_data/test_data/174.png', 95.0],
#  ['test_data/test_data/160.png', 95.0],
#  ['test_data/test_data/606.png', 75.0],
#  ['test_data/test_data/148.png', 95.0],
#  ['test_data/test_data/389.png', 95.0],
#  ['test_data/test_data/376.png', 95.0],
#  ['test_data/test_data/410.png', 100.0],
#  ['test_data/test_data/404.png', 75.0],
#  ['test_data/test_data/362.png', 100.0],
#  ['test_data/test_data/438.png', 95.0],
#  ['test_data/test_data/366.png', 95.0],
#  ['test_data/test_data/400.png', 100.0],
#  ['test_data/test_data/414.png', 110.0],
#  ['test_data/test_data/372.png', 95.0],
#  ['test_data/test_data/428.png', 95.0],
#  ['test_data/test_data/399.png', 95.0],
#  ['test_data/test_data/602.png', 95.0],
#  ['test_data/test_data/164.png', 110.0],
#  ['test_data/test_data/170.png', 110.0],
#  ['test_data/test_data/616.png', 100.0],
#  ['test_data/test_data/158.png', 100.0],
#  ['test_data/test_data/819.png', 100.0],
#  ['test_data/test_data/59.png', 75.0],
#  ['test_data/test_data/825.png', 110.0],
#  ['test_data/test_data/65.png', 100.0],
#  ['test_data/test_data/831.png', 100.0],
#  ['test_data/test_data/71.png', 95.0],
#  ['test_data/test_data/776.png', 105.0],
#  ['test_data/test_data/762.png', 95.0],
#  ['test_data/test_data/992.png', 120.0],
#  ['test_data/test_data/986.png', 75.0],
#  ['test_data/test_data/979.png', 110.0],
#  ['test_data/test_data/789.png', 100.0],
#  ['test_data/test_data/951.png', 95.0],
#  ['test_data/test_data/945.png', 95.0],
#  ['test_data/test_data/212.png', 100.0],
#  ['test_data/test_data/574.png', 110.0],
#  ['test_data/test_data/560.png', 95.0],
#  ['test_data/test_data/206.png', 100.0],
#  ['test_data/test_data/548.png', 95.0],
#  ['test_data/test_data/549.png', 100.0],
#  ['test_data/test_data/561.png', 95.0],
#  ['test_data/test_data/207.png', 100.0],
#  ['test_data/test_data/213.png', 100.0],
#  ['test_data/test_data/575.png', 95.0],
#  ['test_data/test_data/944.png', 95.0],
#  ['test_data/test_data/950.png', 95.0],
#  ['test_data/test_data/788.png', 105.0],
#  ['test_data/test_data/978.png', 110.0],
#  ['test_data/test_data/987.png', 95.0],
#  ['test_data/test_data/993.png', 120.0],
#  ['test_data/test_data/763.png', 100.0],
#  ['test_data/test_data/777.png', 95.0],
#  ['test_data/test_data/70.png', 100.0],
#  ['test_data/test_data/830.png', 100.0],
#  ['test_data/test_data/64.png', 110.0],
#  ['test_data/test_data/824.png', 95.0],
#  ['test_data/test_data/58.png', 105.0],
#  ['test_data/test_data/818.png', 110.0],
#  ['test_data/test_data/159.png', 95.0],
#  ['test_data/test_data/171.png', 95.0],
#  ['test_data/test_data/617.png', 110.0],
#  ['test_data/test_data/603.png', 95.0],
#  ['test_data/test_data/165.png', 100.0],
#  ['test_data/test_data/398.png', 100.0],
#  ['test_data/test_data/429.png', 120.0],
#  ['test_data/test_data/415.png', 95.0],
#  ['test_data/test_data/373.png', 95.0],
#  ['test_data/test_data/367.png', 100.0],
#  ['test_data/test_data/401.png', 95.0],
#  ['test_data/test_data/371.png', 95.0],
#  ['test_data/test_data/417.png', 75.0],
#  ['test_data/test_data/403.png', 95.0],
#  ['test_data/test_data/365.png', 100.0],
#  ['test_data/test_data/359.png', 110.0],
#  ['test_data/test_data/615.png', 100.0],
#  ['test_data/test_data/173.png', 105.0],
#  ['test_data/test_data/167.png', 95.0],
#  ['test_data/test_data/601.png', 110.0],
#  ['test_data/test_data/99.png', 95.0],
#  ['test_data/test_data/629.png', 100.0],
#  ['test_data/test_data/8.png', 100.0],
#  ['test_data/test_data/832.png', 80.0],
#  ['test_data/test_data/72.png', 100.0],
#  ['test_data/test_data/198.png', 95.0],
#  ['test_data/test_data/826.png', 95.0],
#  ['test_data/test_data/66.png', 100.0],
#  ['test_data/test_data/761.png', 95.0],
#  ['test_data/test_data/775.png', 100.0],
#  ['test_data/test_data/985.png', 105.0],
#  ['test_data/test_data/991.png', 100.0],
#  ['test_data/test_data/749.png', 75.0],
#  ['test_data/test_data/946.png', 100.0],
#  ['test_data/test_data/952.png', 75.0],
#  ['test_data/test_data/205.png', 100.0],
#  ['test_data/test_data/563.png', 100.0],
#  ['test_data/test_data/577.png', 110.0],
#  ['test_data/test_data/211.png', 100.0],
#  ['test_data/test_data/239.png', 95.0],
#  ['test_data/test_data/1020.png', 120.0],
#  ['test_data/test_data/1008.png', 100.0],
#  ['test_data/test_data/588.png', 95.0],
#  ['test_data/test_data/589.png', 95.0],
#  ['test_data/test_data/1009.png', 100.0],
#  ['test_data/test_data/238.png', 95.0],
#  ['test_data/test_data/576.png', 120.0],
#  ['test_data/test_data/210.png', 100.0],
#  ['test_data/test_data/204.png', 120.0],
#  ['test_data/test_data/562.png', 105.0],
#  ['test_data/test_data/953.png', 105.0],
#  ['test_data/test_data/947.png', 75.0],
#  ['test_data/test_data/748.png', 110.0],
#  ['test_data/test_data/990.png', 95.0],
#  ['test_data/test_data/984.png', 100.0],
#  ['test_data/test_data/774.png', 95.0],
#  ['test_data/test_data/760.png', 95.0],
#  ['test_data/test_data/199.png', 110.0],
#  ['test_data/test_data/67.png', 95.0],
#  ['test_data/test_data/827.png', 100.0],
#  ['test_data/test_data/73.png', 105.0],
#  ['test_data/test_data/833.png', 95.0],
#  ['test_data/test_data/9.png', 95.0],
#  ['test_data/test_data/628.png', 120.0],
#  ['test_data/test_data/166.png', 95.0],
#  ['test_data/test_data/98.png', 100.0],
#  ['test_data/test_data/600.png', 100.0],
#  ['test_data/test_data/614.png', 95.0],
#  ['test_data/test_data/172.png', 95.0],
#  ['test_data/test_data/358.png', 95.0],
#  ['test_data/test_data/402.png', 100.0],
#  ['test_data/test_data/364.png', 75.0],
#  ['test_data/test_data/370.png', 95.0],
#  ['test_data/test_data/416.png', 110.0],
#  ['test_data/test_data/459.png', 100.0],
#  ['test_data/test_data/317.png', 110.0],
#  ['test_data/test_data/471.png', 100.0],
#  ['test_data/test_data/465.png', 110.0],
#  ['test_data/test_data/303.png', 95.0],
#  ['test_data/test_data/897.png', 95.0],
#  ['test_data/test_data/129.png', 100.0],
#  ['test_data/test_data/883.png', 95.0],
#  ['test_data/test_data/673.png', 100.0],
#  ['test_data/test_data/115.png', 95.0],
#  ['test_data/test_data/101.png', 110.0],
#  ['test_data/test_data/667.png', 95.0],
#  ['test_data/test_data/854.png', 95.0],
#  ['test_data/test_data/14.png', 95.0],
#  ['test_data/test_data/840.png', 100.0],
#  ['test_data/test_data/698.png', 95.0],
#  ['test_data/test_data/868.png', 95.0],
#  ['test_data/test_data/28.png', 100.0],
#  ['test_data/test_data/707.png', 95.0],
#  ['test_data/test_data/713.png', 95.0],
#  ['test_data/test_data/920.png', 105.0],
#  ['test_data/test_data/934.png', 120.0],
#  ['test_data/test_data/908.png', 100.0],
#  ['test_data/test_data/539.png', 95.0],
#  ['test_data/test_data/263.png', 100.0],
#  ['test_data/test_data/505.png', 105.0],
#  ['test_data/test_data/511.png', 110.0],
#  ['test_data/test_data/277.png', 105.0],
#  ['test_data/test_data/288.png', 95.0],
#  ['test_data/test_data/289.png', 95.0],
#  ['test_data/test_data/510.png', 100.0],
#  ['test_data/test_data/276.png', 100.0],
#  ['test_data/test_data/262.png', 100.0],
#  ['test_data/test_data/504.png', 75.0],
#  ['test_data/test_data/538.png', 110.0],
#  ['test_data/test_data/909.png', 95.0],
#  ['test_data/test_data/935.png', 95.0],
#  ['test_data/test_data/921.png', 95.0],
#  ['test_data/test_data/712.png', 95.0],
#  ['test_data/test_data/706.png', 100.0],
#  ['test_data/test_data/29.png', 100.0],
#  ['test_data/test_data/869.png', 95.0],
#  ['test_data/test_data/699.png', 95.0],
#  ['test_data/test_data/841.png', 95.0],
#  ['test_data/test_data/15.png', 75.0],
#  ['test_data/test_data/855.png', 100.0],
#  ['test_data/test_data/100.png', 100.0],
#  ['test_data/test_data/666.png', 95.0],
#  ['test_data/test_data/672.png', 110.0],
#  ['test_data/test_data/114.png', 95.0],
#  ['test_data/test_data/882.png', 95.0],
#  ['test_data/test_data/896.png', 95.0],
#  ['test_data/test_data/128.png', 95.0],
#  ['test_data/test_data/464.png', 95.0],
#  ['test_data/test_data/302.png', 95.0],
#  ['test_data/test_data/316.png', 100.0],
#  ['test_data/test_data/470.png', 95.0],
#  ['test_data/test_data/458.png', 95.0],
#  ['test_data/test_data/328.png', 100.0],
#  ['test_data/test_data/300.png', 95.0],
#  ['test_data/test_data/466.png', 100.0],
#  ['test_data/test_data/472.png', 95.0],
#  ['test_data/test_data/314.png', 110.0],
#  ['test_data/test_data/499.png', 95.0],
#  ['test_data/test_data/658.png', 95.0],
#  ['test_data/test_data/880.png', 100.0],
#  ['test_data/test_data/894.png', 80.0],
#  ['test_data/test_data/664.png', 100.0],
#  ['test_data/test_data/102.png', 120.0],
#  ['test_data/test_data/116.png', 95.0],
#  ['test_data/test_data/670.png', 95.0],
#  ['test_data/test_data/843.png', 95.0],
#  ['test_data/test_data/857.png', 120.0],
#  ['test_data/test_data/17.png', 100.0],
#  ['test_data/test_data/738.png', 120.0],
#  ['test_data/test_data/710.png', 110.0],
#  ['test_data/test_data/704.png', 75.0],
#  ['test_data/test_data/937.png', 95.0],
#  ['test_data/test_data/923.png', 100.0],
#  ['test_data/test_data/248.png', 120.0],
#  ['test_data/test_data/274.png', 100.0],
#  ['test_data/test_data/512.png', 100.0],
#  ['test_data/test_data/506.png', 100.0],
#  ['test_data/test_data/260.png', 95.0],
#  ['test_data/test_data/507.png', 75.0],
#  ['test_data/test_data/261.png', 110.0],
#  ['test_data/test_data/275.png', 100.0],
#  ['test_data/test_data/513.png', 110.0],
#  ['test_data/test_data/249.png', 110.0],
#  ['test_data/test_data/922.png', 100.0],
#  ['test_data/test_data/936.png', 100.0],
#  ['test_data/test_data/705.png', 100.0],
#  ['test_data/test_data/711.png', 100.0],
#  ['test_data/test_data/739.png', 105.0],
#  ['test_data/test_data/16.png', 110.0],
#  ['test_data/test_data/856.png', 95.0],
#  ['test_data/test_data/842.png', 100.0],
#  ['test_data/test_data/117.png', 95.0],
#  ['test_data/test_data/671.png', 100.0],
#  ['test_data/test_data/665.png', 95.0],
#  ['test_data/test_data/103.png', 95.0],
#  ['test_data/test_data/895.png', 95.0],
#  ['test_data/test_data/881.png', 95.0],
#  ['test_data/test_data/659.png', 110.0],
#  ['test_data/test_data/498.png', 120.0],
#  ['test_data/test_data/473.png', 95.0],
#  ['test_data/test_data/315.png', 75.0],
#  ['test_data/test_data/301.png', 100.0],
#  ['test_data/test_data/467.png', 100.0],
#  ['test_data/test_data/329.png', 120.0],
#  ['test_data/test_data/463.png', 75.0],
#  ['test_data/test_data/305.png', 75.0],
#  ['test_data/test_data/311.png', 120.0],
#  ['test_data/test_data/477.png', 95.0],
#  ['test_data/test_data/339.png', 110.0],
#  ['test_data/test_data/488.png', 100.0],
#  ['test_data/test_data/107.png', 95.0],
#  ['test_data/test_data/661.png', 110.0],
#  ['test_data/test_data/675.png', 95.0],
#  ['test_data/test_data/113.png', 100.0],
#  ['test_data/test_data/885.png', 100.0],
#  ['test_data/test_data/649.png', 95.0],
#  ['test_data/test_data/891.png', 95.0],
#  ['test_data/test_data/846.png', 75.0],
#  ['test_data/test_data/852.png', 95.0],
#  ['test_data/test_data/12.png', 110.0],
#  ['test_data/test_data/715.png', 95.0],
#  ['test_data/test_data/701.png', 100.0],
#  ['test_data/test_data/729.png', 95.0],
#  ['test_data/test_data/932.png', 100.0],
#  ['test_data/test_data/926.png', 75.0],
#  ['test_data/test_data/517.png', 100.0],
#  ['test_data/test_data/271.png', 100.0],
#  ['test_data/test_data/265.png', 95.0],
#  ['test_data/test_data/503.png', 95.0],
#  ['test_data/test_data/259.png', 75.0],
#  ['test_data/test_data/258.png', 110.0],
#  ['test_data/test_data/264.png', 100.0],
#  ['test_data/test_data/502.png', 100.0],
#  ['test_data/test_data/516.png', 95.0],
#  ['test_data/test_data/270.png', 95.0],
#  ['test_data/test_data/927.png', 120.0],
#  ['test_data/test_data/933.png', 120.0],
#  ['test_data/test_data/728.png', 100.0],
#  ['test_data/test_data/700.png', 95.0],
#  ['test_data/test_data/714.png', 95.0],
#  ['test_data/test_data/13.png', 95.0],
#  ['test_data/test_data/853.png', 95.0],
#  ['test_data/test_data/847.png', 120.0],
#  ['test_data/test_data/890.png', 100.0],
#  ['test_data/test_data/648.png', 95.0],
#  ['test_data/test_data/884.png', 100.0],
#  ['test_data/test_data/674.png', 100.0],
#  ['test_data/test_data/112.png', 95.0],
#  ['test_data/test_data/106.png', 95.0],
#  ['test_data/test_data/660.png', 105.0],
#  ['test_data/test_data/489.png', 75.0],
#  ['test_data/test_data/338.png', 105.0],
#  ['test_data/test_data/310.png', 100.0],
#  ['test_data/test_data/476.png', 120.0],
#  ['test_data/test_data/462.png', 100.0],
#  ['test_data/test_data/304.png', 100.0],
#  ['test_data/test_data/474.png', 95.0],
#  ['test_data/test_data/312.png', 75.0],
#  ['test_data/test_data/306.png', 100.0],
#  ['test_data/test_data/460.png', 75.0],
#  ['test_data/test_data/448.png', 95.0],
#  ['test_data/test_data/110.png', 110.0],
#  ['test_data/test_data/676.png', 75.0],
#  ['test_data/test_data/662.png', 95.0],
#  ['test_data/test_data/104.png', 95.0],
#  ['test_data/test_data/892.png', 80.0],
#  ['test_data/test_data/886.png', 95.0],
#  ['test_data/test_data/138.png', 95.0],
#  ['test_data/test_data/879.png', 95.0],
#  ['test_data/test_data/39.png', 95.0],
#  ['test_data/test_data/851.png', 110.0],
#  ['test_data/test_data/689.png', 110.0],
#  ['test_data/test_data/11.png', 95.0],
#  ['test_data/test_data/845.png', 105.0],
#  ['test_data/test_data/702.png', 100.0],
#  ['test_data/test_data/716.png', 95.0],
#  ['test_data/test_data/919.png', 100.0],
#  ['test_data/test_data/925.png', 100.0],
#  ['test_data/test_data/931.png', 115.0],
#  ['test_data/test_data/500.png', 95.0],
#  ['test_data/test_data/266.png', 100.0],
#  ['test_data/test_data/272.png', 95.0],
#  ['test_data/test_data/514.png', 100.0],
#  ['test_data/test_data/528.png', 110.0],
#  ['test_data/test_data/299.png', 95.0],
#  ['test_data/test_data/298.png', 95.0],
#  ['test_data/test_data/529.png', 95.0],
#  ['test_data/test_data/273.png', 110.0],
#  ['test_data/test_data/515.png', 95.0],
#  ['test_data/test_data/501.png', 100.0],
#  ['test_data/test_data/267.png', 100.0],
#  ['test_data/test_data/930.png', 105.0],
#  ['test_data/test_data/924.png', 100.0],
#  ['test_data/test_data/918.png', 100.0],
#  ['test_data/test_data/717.png', 75.0],
#  ['test_data/test_data/703.png', 95.0],
#  ['test_data/test_data/844.png', 95.0],
#  ['test_data/test_data/10.png', 75.0],
#  ['test_data/test_data/688.png', 95.0],
#  ['test_data/test_data/850.png', 95.0],
#  ['test_data/test_data/38.png', 110.0],
#  ['test_data/test_data/878.png', 95.0],
#  ['test_data/test_data/887.png', 95.0],
#  ['test_data/test_data/139.png', 95.0],
#  ['test_data/test_data/893.png', 95.0],
#  ['test_data/test_data/663.png', 105.0],
#  ['test_data/test_data/105.png', 75.0],
#  ['test_data/test_data/111.png', 95.0],
#  ['test_data/test_data/677.png', 75.0],
#  ['test_data/test_data/449.png', 100.0],
#  ['test_data/test_data/307.png', 110.0],
#  ['test_data/test_data/461.png', 105.0],
#  ['test_data/test_data/475.png', 120.0],
#  ['test_data/test_data/313.png', 120.0],
#  ['test_data/test_data/478.png', 95.0],
#  ['test_data/test_data/336.png', 95.0],
#  ['test_data/test_data/450.png', 120.0],
#  ['test_data/test_data/444.png', 110.0],
#  ['test_data/test_data/322.png', 95.0],
#  ['test_data/test_data/493.png', 95.0],
#  ['test_data/test_data/487.png', 100.0],
#  ['test_data/test_data/108.png', 75.0],
#  ['test_data/test_data/652.png', 100.0],
#  ['test_data/test_data/134.png', 100.0],
#  ['test_data/test_data/120.png', 100.0],
#  ['test_data/test_data/646.png', 100.0],
#  ['test_data/test_data/875.png', 95.0],
#  ['test_data/test_data/35.png', 100.0],
#  ['test_data/test_data/861.png', 100.0],
#  ['test_data/test_data/21.png', 120.0],
#  ['test_data/test_data/849.png', 110.0],
#  ['test_data/test_data/691.png', 100.0],
#  ['test_data/test_data/685.png', 100.0],
#  ['test_data/test_data/726.png', 100.0],
#  ['test_data/test_data/732.png', 95.0],
#  ['test_data/test_data/901.png', 100.0],
#  ['test_data/test_data/915.png', 95.0],
#  ['test_data/test_data/929.png', 100.0],
#  ['test_data/test_data/518.png', 75.0],
#  ['test_data/test_data/242.png', 100.0],
#  ['test_data/test_data/524.png', 95.0],
#  ['test_data/test_data/530.png', 95.0],
#  ['test_data/test_data/256.png', 100.0],
#  ['test_data/test_data/281.png', 95.0],
#  ['test_data/test_data/295.png', 110.0],
#  ['test_data/test_data/294.png', 100.0],
#  ['test_data/test_data/280.png', 95.0],
#  ['test_data/test_data/531.png', 105.0],
#  ['test_data/test_data/257.png', 95.0],
#  ['test_data/test_data/243.png', 100.0],
#  ['test_data/test_data/525.png', 110.0],
#  ['test_data/test_data/519.png', 95.0],
#  ['test_data/test_data/928.png', 110.0],
#  ['test_data/test_data/914.png', 100.0],
#  ['test_data/test_data/900.png', 95.0],
#  ['test_data/test_data/733.png', 100.0],
#  ['test_data/test_data/727.png', 100.0],
#  ['test_data/test_data/684.png', 95.0],
#  ['test_data/test_data/690.png', 95.0],
#  ['test_data/test_data/848.png', 100.0],
#  ['test_data/test_data/20.png', 75.0],
#  ['test_data/test_data/860.png', 95.0],
#  ['test_data/test_data/34.png', 100.0],
#  ['test_data/test_data/874.png', 95.0],
#  ['test_data/test_data/121.png', 95.0],
#  ['test_data/test_data/647.png', 95.0],
#  ['test_data/test_data/653.png', 95.0],
#  ['test_data/test_data/135.png', 110.0],
#  ['test_data/test_data/109.png', 110.0],
#  ['test_data/test_data/486.png', 95.0],
#  ['test_data/test_data/492.png', 100.0],
#  ['test_data/test_data/445.png', 95.0],
#  ['test_data/test_data/323.png', 100.0],
#  ['test_data/test_data/337.png', 95.0],
#  ['test_data/test_data/451.png', 100.0],
#  ['test_data/test_data/479.png', 110.0],
#  ['test_data/test_data/309.png', 95.0],
#  ['test_data/test_data/321.png', 120.0],
#  ['test_data/test_data/447.png', 100.0],
#  ['test_data/test_data/453.png', 95.0],
#  ['test_data/test_data/335.png', 105.0],
#  ['test_data/test_data/484.png', 95.0],
#  ['test_data/test_data/490.png', 95.0],
#  ['test_data/test_data/679.png', 95.0],
#  ['test_data/test_data/645.png', 100.0],
#  ['test_data/test_data/123.png', 120.0],
#  ['test_data/test_data/137.png', 95.0],
#  ['test_data/test_data/651.png', 100.0],
#  ['test_data/test_data/889.png', 105.0],
#  ['test_data/test_data/862.png', 95.0],
#  ['test_data/test_data/22.png', 95.0],
#  ['test_data/test_data/876.png', 105.0],
#  ['test_data/test_data/36.png', 100.0],
#  ['test_data/test_data/686.png', 95.0],
#  ['test_data/test_data/692.png', 95.0],
#  ['test_data/test_data/719.png', 75.0],
#  ['test_data/test_data/731.png', 95.0],
#  ['test_data/test_data/725.png', 100.0],
#  ['test_data/test_data/916.png', 95.0],
#  ['test_data/test_data/902.png', 95.0],
#  ['test_data/test_data/269.png', 110.0],
#  ['test_data/test_data/255.png', 100.0],
#  ['test_data/test_data/533.png', 110.0],
#  ['test_data/test_data/527.png', 110.0],
#  ['test_data/test_data/241.png', 95.0],
#  ['test_data/test_data/296.png', 95.0],
#  ['test_data/test_data/282.png', 110.0],
#  ['test_data/test_data/283.png', 75.0],
#  ['test_data/test_data/297.png', 95.0],
#  ['test_data/test_data/526.png', 95.0],
#  ['test_data/test_data/240.png', 95.0],
#  ['test_data/test_data/254.png', 110.0],
#  ['test_data/test_data/532.png', 95.0],
#  ['test_data/test_data/268.png', 120.0],
#  ['test_data/test_data/903.png', 110.0],
#  ['test_data/test_data/917.png', 100.0],
#  ['test_data/test_data/724.png', 100.0],
#  ['test_data/test_data/730.png', 95.0],
#  ['test_data/test_data/718.png', 100.0],
#  ['test_data/test_data/693.png', 100.0],
#  ['test_data/test_data/687.png', 95.0],
#  ['test_data/test_data/37.png', 95.0],
#  ['test_data/test_data/877.png', 100.0],
#  ['test_data/test_data/23.png', 95.0],
#  ['test_data/test_data/863.png', 95.0],
#  ['test_data/test_data/136.png', 105.0],
#  ['test_data/test_data/888.png', 105.0],
#  ['test_data/test_data/650.png', 95.0],
#  ['test_data/test_data/644.png', 100.0],
#  ['test_data/test_data/122.png', 100.0],
#  ['test_data/test_data/678.png', 110.0],
#  ['test_data/test_data/491.png', 95.0],
#  ['test_data/test_data/485.png', 120.0],
#  ['test_data/test_data/452.png', 100.0],
#  ['test_data/test_data/334.png', 95.0],
#  ['test_data/test_data/320.png', 95.0],
#  ['test_data/test_data/446.png', 100.0],
#  ['test_data/test_data/308.png', 105.0],
#  ['test_data/test_data/442.png', 95.0],
#  ['test_data/test_data/324.png', 110.0],
#  ['test_data/test_data/330.png', 110.0],
#  ['test_data/test_data/456.png', 100.0],
#  ['test_data/test_data/318.png', 75.0],
#  ['test_data/test_data/481.png', 120.0],
#  ['test_data/test_data/495.png', 95.0],
#  ['test_data/test_data/126.png', 110.0],
#  ['test_data/test_data/640.png', 110.0],
#  ['test_data/test_data/898.png', 95.0],
#  ['test_data/test_data/654.png', 100.0],
#  ['test_data/test_data/132.png', 95.0],
#  ['test_data/test_data/668.png', 95.0],
#  ['test_data/test_data/683.png', 75.0],
#  ['test_data/test_data/697.png', 95.0],
#  ['test_data/test_data/867.png', 95.0],
#  ['test_data/test_data/27.png', 95.0],
#  ['test_data/test_data/873.png', 100.0],
#  ['test_data/test_data/33.png', 100.0],
#  ['test_data/test_data/734.png', 95.0],
#  ['test_data/test_data/720.png', 95.0],
#  ['test_data/test_data/708.png', 105.0],
#  ['test_data/test_data/913.png', 105.0],
#  ['test_data/test_data/907.png', 110.0],
#  ['test_data/test_data/536.png', 120.0],
#  ['test_data/test_data/250.png', 110.0],
#  ['test_data/test_data/244.png', 110.0],
#  ['test_data/test_data/522.png', 95.0],
#  ['test_data/test_data/278.png', 100.0],
#  ['test_data/test_data/293.png', 95.0],
#  ['test_data/test_data/287.png', 95.0],
#  ['test_data/test_data/286.png', 100.0],
#  ['test_data/test_data/292.png', 100.0],
#  ['test_data/test_data/279.png', 110.0],
#  ['test_data/test_data/245.png', 95.0],
#  ['test_data/test_data/523.png', 100.0],
#  ['test_data/test_data/537.png', 100.0],
#  ['test_data/test_data/251.png', 95.0],
#  ['test_data/test_data/906.png', 100.0],
#  ['test_data/test_data/912.png', 95.0],
#  ['test_data/test_data/709.png', 120.0],
#  ['test_data/test_data/721.png', 100.0],
#  ['test_data/test_data/735.png', 95.0],
#  ['test_data/test_data/32.png', 105.0],
#  ['test_data/test_data/872.png', 95.0],
#  ['test_data/test_data/26.png', 100.0],
#  ['test_data/test_data/866.png', 95.0],
#  ['test_data/test_data/696.png', 100.0],
#  ['test_data/test_data/682.png', 100.0],
#  ['test_data/test_data/669.png', 95.0],
#  ['test_data/test_data/655.png', 95.0],
#  ['test_data/test_data/133.png', 110.0],
#  ['test_data/test_data/127.png', 75.0],
#  ['test_data/test_data/899.png', 100.0],
#  ['test_data/test_data/641.png', 105.0],
#  ['test_data/test_data/494.png', 100.0],
#  ['test_data/test_data/480.png', 95.0],
#  ['test_data/test_data/319.png', 95.0],
#  ['test_data/test_data/331.png', 110.0],
#  ['test_data/test_data/457.png', 95.0],
#  ['test_data/test_data/443.png', 95.0],
#  ['test_data/test_data/325.png', 105.0],
#  ['test_data/test_data/455.png', 110.0],
#  ['test_data/test_data/333.png', 105.0],
#  ['test_data/test_data/327.png', 95.0],
#  ['test_data/test_data/441.png', 95.0],
#  ['test_data/test_data/469.png', 110.0],
#  ['test_data/test_data/496.png', 75.0],
#  ['test_data/test_data/482.png', 95.0],
#  ['test_data/test_data/131.png', 105.0],
#  ['test_data/test_data/657.png', 95.0],
#  ['test_data/test_data/643.png', 95.0],
#  ['test_data/test_data/125.png', 75.0],
#  ['test_data/test_data/119.png', 110.0],
#  ['test_data/test_data/694.png', 95.0],
#  ['test_data/test_data/858.png', 95.0],
#  ['test_data/test_data/680.png', 100.0],
#  ['test_data/test_data/18.png', 105.0],
#  ['test_data/test_data/870.png', 95.0],
#  ['test_data/test_data/30.png', 100.0],
#  ['test_data/test_data/864.png', 95.0],
#  ['test_data/test_data/24.png', 105.0],
#  ['test_data/test_data/723.png', 110.0],
#  ['test_data/test_data/737.png', 100.0],
#  ['test_data/test_data/938.png', 95.0],
#  ['test_data/test_data/904.png', 115.0],
#  ['test_data/test_data/910.png', 95.0],
#  ['test_data/test_data/521.png', 100.0],
#  ['test_data/test_data/247.png', 95.0],
#  ['test_data/test_data/253.png', 105.0],
#  ['test_data/test_data/535.png', 95.0],
#  ['test_data/test_data/509.png', 95.0],
#  ['test_data/test_data/284.png', 100.0],
#  ['test_data/test_data/290.png', 100.0],
#  ['test_data/test_data/291.png', 100.0],
#  ['test_data/test_data/285.png', 95.0],
#  ['test_data/test_data/508.png', 100.0],
#  ['test_data/test_data/252.png', 95.0],
#  ['test_data/test_data/534.png', 100.0],
#  ['test_data/test_data/520.png', 100.0],
#  ['test_data/test_data/246.png', 120.0],
#  ['test_data/test_data/911.png', 105.0],
#  ['test_data/test_data/905.png', 120.0],
#  ['test_data/test_data/939.png', 100.0],
#  ['test_data/test_data/736.png', 95.0],
#  ['test_data/test_data/722.png', 75.0],
#  ['test_data/test_data/25.png', 100.0],
#  ['test_data/test_data/865.png', 100.0],
#  ['test_data/test_data/31.png', 95.0],
#  ['test_data/test_data/871.png', 95.0],
#  ['test_data/test_data/19.png', 95.0],
#  ['test_data/test_data/681.png', 100.0],
#  ['test_data/test_data/859.png', 100.0],
#  ['test_data/test_data/695.png', 75.0],
#  ['test_data/test_data/118.png', 95.0],
#  ['test_data/test_data/642.png', 100.0],
#  ['test_data/test_data/124.png', 95.0],
#  ['test_data/test_data/130.png', 95.0],
#  ['test_data/test_data/656.png', 95.0],
#  ['test_data/test_data/483.png', 110.0],
#  ['test_data/test_data/497.png', 100.0],
#  ['test_data/test_data/468.png', 95.0],
#  ['test_data/test_data/326.png', 100.0],
#  ['test_data/test_data/440.png', 75.0],
#  ['test_data/test_data/454.png', 100.0],
#  ['test_data/test_data/332.png', 95.0],
#  ['test_data/test_data/369.png', 95.0],
#  ['test_data/test_data/433.png', 100.0],
#  ['test_data/test_data/355.png', 100.0],
#  ['test_data/test_data/341.png', 95.0],
#  ['test_data/test_data/427.png', 100.0],
#  ['test_data/test_data/396.png', 95.0],
#  ['test_data/test_data/382.png', 105.0],
#  ['test_data/test_data/95.png', 100.0],
#  ['test_data/test_data/81.png', 100.0],
#  ['test_data/test_data/619.png', 95.0],
#  ['test_data/test_data/157.png', 100.0],
#  ['test_data/test_data/631.png', 110.0],
#  ['test_data/test_data/625.png', 120.0],
#  ['test_data/test_data/143.png', 95.0],
#  ['test_data/test_data/4.png', 75.0],
#  ['test_data/test_data/816.png', 75.0],
#  ['test_data/test_data/56.png', 105.0],
#  ['test_data/test_data/802.png', 110.0],
#  ['test_data/test_data/42.png', 95.0],
#  ['test_data/test_data/194.png', 95.0],
#  ['test_data/test_data/180.png', 95.0],
#  ['test_data/test_data/779.png', 120.0],
#  ['test_data/test_data/745.png', 100.0],
#  ['test_data/test_data/989.png', 100.0],
#  ['test_data/test_data/751.png', 95.0],
#  ['test_data/test_data/962.png', 75.0],
#  ['test_data/test_data/976.png', 100.0],
#  ['test_data/test_data/786.png', 105.0],
#  ['test_data/test_data/792.png', 95.0],
#  ['test_data/test_data/209.png', 120.0],
#  ['test_data/test_data/547.png', 100.0],
#  ['test_data/test_data/221.png', 100.0],
#  ['test_data/test_data/235.png', 110.0],
#  ['test_data/test_data/553.png', 75.0],
#  ['test_data/test_data/584.png', 100.0],
#  ['test_data/test_data/1010.png', 95.0],
#  ['test_data/test_data/1004.png', 100.0],
#  ['test_data/test_data/590.png', 95.0],
#  ['test_data/test_data/591.png', 110.0],
#  ['test_data/test_data/1005.png', 100.0],
#  ['test_data/test_data/1011.png', 95.0],
#  ['test_data/test_data/585.png', 100.0],
#  ['test_data/test_data/234.png', 95.0],
#  ['test_data/test_data/552.png', 80.0],
#  ['test_data/test_data/546.png', 110.0],
#  ['test_data/test_data/220.png', 100.0],
#  ['test_data/test_data/208.png', 95.0],
#  ['test_data/test_data/793.png', 120.0],
#  ['test_data/test_data/787.png', 95.0],
#  ['test_data/test_data/977.png', 75.0],
#  ['test_data/test_data/963.png', 100.0],
#  ['test_data/test_data/750.png', 100.0],
#  ['test_data/test_data/988.png', 100.0],
#  ['test_data/test_data/744.png', 95.0],
#  ['test_data/test_data/778.png', 95.0],
#  ['test_data/test_data/181.png', 95.0],
#  ['test_data/test_data/195.png', 95.0],
#  ['test_data/test_data/43.png', 95.0],
#  ['test_data/test_data/803.png', 100.0],
#  ['test_data/test_data/5.png', 75.0],
#  ['test_data/test_data/57.png', 95.0],
#  ['test_data/test_data/817.png', 110.0],
#  ['test_data/test_data/624.png', 110.0],
#  ['test_data/test_data/142.png', 100.0],
#  ['test_data/test_data/156.png', 100.0],
#  ['test_data/test_data/630.png', 95.0],
#  ['test_data/test_data/618.png', 110.0],
#  ['test_data/test_data/80.png', 105.0],
#  ['test_data/test_data/94.png', 75.0],
#  ['test_data/test_data/383.png', 95.0],
#  ['test_data/test_data/397.png', 75.0],
#  ['test_data/test_data/340.png', 95.0],
#  ['test_data/test_data/426.png', 95.0],
#  ['test_data/test_data/432.png', 95.0],
#  ['test_data/test_data/354.png', 95.0],
#  ['test_data/test_data/368.png', 100.0],
#  ['test_data/test_data/418.png', 100.0],
#  ['test_data/test_data/424.png', 95.0],
#  ['test_data/test_data/342.png', 100.0],
#  ['test_data/test_data/356.png', 95.0],
#  ['test_data/test_data/430.png', 95.0],
#  ['test_data/test_data/381.png', 120.0],
#  ['test_data/test_data/395.png', 120.0],
#  ['test_data/test_data/82.png', 100.0],
#  ['test_data/test_data/96.png', 95.0],
#  ['test_data/test_data/168.png', 95.0],
#  ['test_data/test_data/140.png', 105.0],
#  ['test_data/test_data/626.png', 95.0],
#  ['test_data/test_data/632.png', 95.0],
#  ['test_data/test_data/154.png', 95.0],
#  ['test_data/test_data/801.png', 95.0],
#  ['test_data/test_data/41.png', 95.0],
#  ['test_data/test_data/815.png', 95.0],
#  ['test_data/test_data/55.png', 100.0],
#  ['test_data/test_data/7.png', 100.0],
#  ['test_data/test_data/183.png', 95.0],
#  ['test_data/test_data/829.png', 75.0],
#  ['test_data/test_data/69.png', 95.0],
#  ['test_data/test_data/197.png', 100.0],
#  ['test_data/test_data/752.png', 120.0],
#  ['test_data/test_data/746.png', 100.0],
#  ['test_data/test_data/975.png', 105.0],
#  ['test_data/test_data/961.png', 95.0],
#  ['test_data/test_data/791.png', 95.0],
#  ['test_data/test_data/949.png', 100.0],
#  ['test_data/test_data/785.png', 95.0],
#  ['test_data/test_data/578.png', 100.0],
#  ['test_data/test_data/550.png', 95.0],
#  ['test_data/test_data/236.png', 100.0],
#  ['test_data/test_data/222.png', 110.0],
#  ['test_data/test_data/544.png', 100.0],
#  ['test_data/test_data/1007.png', 120.0],
#  ['test_data/test_data/593.png', 95.0],
#  ['test_data/test_data/587.png', 100.0],
#  ['test_data/test_data/1013.png', 100.0],
#  ['test_data/test_data/1012.png', 100.0],
#  ['test_data/test_data/586.png', 120.0],
#  ['test_data/test_data/592.png', 100.0],
#  ['test_data/test_data/1006.png', 95.0],
#  ['test_data/test_data/223.png', 110.0],
#  ['test_data/test_data/545.png', 95.0],
#  ['test_data/test_data/551.png', 95.0],
#  ['test_data/test_data/237.png', 120.0],
#  ['test_data/test_data/579.png', 95.0],
#  ['test_data/test_data/784.png', 95.0],
#  ['test_data/test_data/948.png', 95.0],
#  ['test_data/test_data/790.png', 110.0],
#  ['test_data/test_data/960.png', 95.0],
#  ['test_data/test_data/974.png', 95.0],
#  ['test_data/test_data/747.png', 95.0],
#  ['test_data/test_data/753.png', 100.0],
#  ['test_data/test_data/68.png', 95.0],
#  ['test_data/test_data/828.png', 120.0],
#  ['test_data/test_data/196.png', 75.0],
#  ['test_data/test_data/182.png', 100.0],
#  ['test_data/test_data/54.png', 110.0],
#  ['test_data/test_data/814.png', 110.0],
#  ['test_data/test_data/6.png', 100.0],
#  ['test_data/test_data/40.png', 100.0],
#  ['test_data/test_data/800.png', 100.0],
#  ['test_data/test_data/633.png', 110.0],
#  ['test_data/test_data/155.png', 95.0],
#  ['test_data/test_data/141.png', 100.0],
#  ['test_data/test_data/627.png', 75.0],
#  ['test_data/test_data/97.png', 95.0],
#  ['test_data/test_data/169.png', 95.0],
#  ['test_data/test_data/83.png', 100.0],
#  ['test_data/test_data/394.png', 95.0],
#  ['test_data/test_data/380.png', 95.0],
#  ['test_data/test_data/357.png', 95.0],
#  ['test_data/test_data/431.png', 110.0],
#  ['test_data/test_data/425.png', 95.0],
#  ['test_data/test_data/343.png', 95.0],
#  ['test_data/test_data/419.png', 105.0],
#  ['test_data/test_data/347.png', 95.0],
#  ['test_data/test_data/421.png', 100.0],
#  ['test_data/test_data/435.png', 95.0],
#  ['test_data/test_data/353.png', 95.0],
#  ['test_data/test_data/409.png', 95.0],
#  ['test_data/test_data/384.png', 95.0],
#  ['test_data/test_data/390.png', 100.0],
#  ['test_data/test_data/623.png', 95.0],
#  ['test_data/test_data/145.png', 95.0],
#  ['test_data/test_data/151.png', 105.0],
#  ['test_data/test_data/637.png', 100.0],
#  ['test_data/test_data/87.png', 95.0],
#  ['test_data/test_data/179.png', 95.0],
#  ['test_data/test_data/93.png', 100.0],
#  ['test_data/test_data/838.png', 95.0],
#  ['test_data/test_data/78.png', 95.0],
#  ['test_data/test_data/186.png', 110.0],
#  ['test_data/test_data/192.png', 95.0],
#  ['test_data/test_data/804.png', 95.0],
#  ['test_data/test_data/44.png', 95.0],
#  ['test_data/test_data/2.png', 110.0],
#  ['test_data/test_data/810.png', 110.0],
#  ['test_data/test_data/50.png', 120.0],
#  ['test_data/test_data/757.png', 95.0],
#  ['test_data/test_data/743.png', 100.0],
#  ['test_data/test_data/794.png', 75.0],
#  ['test_data/test_data/780.png', 95.0],
#  ['test_data/test_data/958.png', 80.0],
#  ['test_data/test_data/970.png', 75.0],
#  ['test_data/test_data/964.png', 95.0],
#  ['test_data/test_data/233.png', 110.0],
#  ['test_data/test_data/555.png', 75.0],
#  ['test_data/test_data/541.png', 75.0],
#  ['test_data/test_data/227.png', 95.0],
#  ['test_data/test_data/569.png', 95.0],
#  ['test_data/test_data/1002.png', 95.0],
#  ['test_data/test_data/596.png', 95.0],
#  ['test_data/test_data/582.png', 95.0],
#  ['test_data/test_data/1016.png', 95.0],
#  ['test_data/test_data/1017.png', 100.0],
#  ['test_data/test_data/583.png', 75.0],
#  ['test_data/test_data/597.png', 120.0],
#  ['test_data/test_data/1003.png', 95.0],
#  ['test_data/test_data/568.png', 100.0],
#  ['test_data/test_data/540.png', 95.0],
#  ['test_data/test_data/226.png', 120.0],
#  ['test_data/test_data/232.png', 95.0],
#  ['test_data/test_data/554.png', 110.0],
#  ['test_data/test_data/965.png', 95.0],
#  ['test_data/test_data/971.png', 110.0],
#  ['test_data/test_data/959.png', 95.0],
#  ['test_data/test_data/781.png', 95.0],
#  ['test_data/test_data/795.png', 95.0],
#  ['test_data/test_data/742.png', 95.0],
#  ['test_data/test_data/756.png', 100.0],
#  ['test_data/test_data/3.png', 95.0],
#  ['test_data/test_data/51.png', 95.0],
#  ['test_data/test_data/811.png', 110.0],
#  ['test_data/test_data/45.png', 75.0],
#  ['test_data/test_data/805.png', 95.0],
#  ['test_data/test_data/193.png', 100.0],
#  ['test_data/test_data/79.png', 95.0],
#  ['test_data/test_data/839.png', 100.0],
#  ['test_data/test_data/187.png', 95.0],
#  ['test_data/test_data/92.png', 95.0],
#  ['test_data/test_data/86.png', 100.0],
#  ['test_data/test_data/178.png', 110.0],
#  ['test_data/test_data/150.png', 95.0],
#  ['test_data/test_data/636.png', 95.0],
#  ['test_data/test_data/622.png', 95.0],
#  ['test_data/test_data/144.png', 95.0],
#  ['test_data/test_data/391.png', 75.0],
#  ['test_data/test_data/385.png', 100.0],
#  ['test_data/test_data/408.png', 100.0],
#  ['test_data/test_data/434.png', 100.0],
#  ['test_data/test_data/352.png', 95.0],
#  ['test_data/test_data/346.png', 110.0],
#  ['test_data/test_data/420.png', 95.0],
#  ['test_data/test_data/350.png', 100.0],
#  ['test_data/test_data/436.png', 95.0],
#  ['test_data/test_data/422.png', 100.0],
#  ['test_data/test_data/344.png', 100.0],
#  ['test_data/test_data/378.png', 95.0],
#  ['test_data/test_data/393.png', 95.0],
#  ['test_data/test_data/387.png', 95.0],
#  ['test_data/test_data/634.png', 95.0],
#  ['test_data/test_data/152.png', 100.0],
#  ['test_data/test_data/146.png', 120.0],
#  ['test_data/test_data/620.png', 95.0],
#  ['test_data/test_data/608.png', 95.0],
#  ['test_data/test_data/90.png', 75.0],
#  ['test_data/test_data/84.png', 95.0],
#  ['test_data/test_data/191.png', 95.0],
#  ['test_data/test_data/185.png', 95.0],
#  ['test_data/test_data/813.png', 100.0],
#  ['test_data/test_data/53.png', 110.0],
#  ['test_data/test_data/1.png', 95.0],
#  ['test_data/test_data/807.png', 110.0],
#  ['test_data/test_data/47.png', 110.0],
#  ['test_data/test_data/998.png', 100.0],
#  ['test_data/test_data/740.png', 95.0],
#  ['test_data/test_data/754.png', 95.0],
#  ['test_data/test_data/768.png', 95.0],
#  ['test_data/test_data/783.png', 100.0],
#  ['test_data/test_data/797.png', 95.0],
#  ['test_data/test_data/967.png', 100.0],
#  ['test_data/test_data/973.png', 95.0],
#  ['test_data/test_data/224.png', 120.0],
#  ['test_data/test_data/542.png', 100.0],
#  ['test_data/test_data/556.png', 110.0],
#  ['test_data/test_data/230.png', 100.0],
#  ['test_data/test_data/218.png', 100.0],
#  ['test_data/test_data/581.png', 95.0],
#  ['test_data/test_data/1015.png', 95.0],
#  ['test_data/test_data/1001.png', 95.0],
#  ['test_data/test_data/595.png', 75.0],
#  ['test_data/test_data/594.png', 100.0],
#  ['test_data/test_data/1000.png', 95.0],
#  ['test_data/test_data/1014.png', 120.0],
#  ['test_data/test_data/580.png', 95.0],
#  ['test_data/test_data/219.png', 120.0],
#  ['test_data/test_data/557.png', 100.0],
#  ['test_data/test_data/231.png', 95.0],
#  ['test_data/test_data/225.png', 95.0],
#  ['test_data/test_data/543.png', 120.0],
#  ['test_data/test_data/972.png', 95.0],
#  ['test_data/test_data/966.png', 95.0],
#  ['test_data/test_data/796.png', 95.0],
#  ['test_data/test_data/782.png', 95.0],
#  ['test_data/test_data/769.png', 95.0],
#  ['test_data/test_data/755.png', 100.0],
#  ['test_data/test_data/741.png', 100.0],
#  ['test_data/test_data/999.png', 120.0],
#  ...]
